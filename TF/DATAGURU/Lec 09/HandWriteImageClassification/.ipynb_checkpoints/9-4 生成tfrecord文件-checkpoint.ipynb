# %%
import tensorflow as tf
import os 
import random
import math
import sys

# %%
# 验证集数量
_NUM_TEST = 500
# 随机种子
_RANDOM_SEED = 0
# 数据块
_NUM_SHARDS = 4 
# 数据集路径
DATASET_DIR = 'slim/images/'
# 标签文件名字
LABELS_FILENAME = 'labels.txt'

# %%
# 定义tfrecord文件的路径+名字
def _get_dataset_filename(dataset_dir, split_name, shard_id):
    output_filename = 'image_%s_%05d-of-%05d.tfrecord' % (split_name, shard_id, _NUM_SHARDS)
    return os.path.join(dataset_dir, output_filename)

# %%
# 判断tfrecord文件是否存在
def _dataset_exists(dataset_dir):
    for split_name in ['train', 'test']:
        for shard_id in range(_NUM_SHARDS):
            # 定义tfrecord文件的路径+名字
            output_filename = _get_dataset_filename(dataset_dir, split_name, shard_id)
        if not tf.gfile.Exists(output_filename):
            return False
    return True

# %%
# 获取所有文件以及分类
def _get_filenames_and_classes(dataset_dir):
    # 数据目录
    directories = []
    # 分类名称
    class_names = []
    for filename in os.listdir(dataset_dir):
        # 合并文件路径
        path = os.path.join(dataset_dir, filename)
        # 判断该路径是否为目录
        if os.path.isdir(path):
            # 加入数据目录
            directories.append(path)
            # 加入类别名称
            class_names.append(filename)
        
    photo_filenames = []
    # 循环每个分类的文件夹
    for directory in directories:
        for filename in os.listdir(directory):
            path = os.path.join(directory, filename)
            # 把图片加入图片列表
            photo_filenames.append(path)
    
    return photo_filenames, class_names

# %%
def int64_feature(values):
    if not isinstance(values, (tuple, list)):
        values = [values]
    return tf.train.Feature(int64_list = tf.train.Int64List(value=values))

# %%
def bytes_feature(values):
    return tf.train.Feature(bytes_list = tf.train.BytesList(value=[values]))

# %%
def image_to_tfexample(image_data, image_format, class_id):
    # Abstract base class for protocol messages.
    return tf.train.Example(features=tf.train.Features(feature={
        'image/encoded': bytes_feature(image_data),
        'image/format': bytes_feature(image_format),
        'image/class/label': int64_feature(class_id),
        }))

# %%
def write_label_file(labels_to_class_names, dataset_dir, filename=LABELS_FILENAME):
    labels_filename = os.path.join(dataset_dir, filename)
    with tf.gfile.Open(labels_filename, 'w') as f:
        for label in labels_to_class_names:
            class_name = labels_to_class_names[label]
            f.write('%d : %s \n'% (label, class_name))

# %%
# 将数据转换为TFRecord格式
def _convert_dataset(split_name, filenames, class_names_to_ids, dataset_dir):
    assert split_name in ['train', 'test']
    
    # 计算每个数据块有多少数据（数据块指的是train或test分成指定的_NUM_SHARDS块）
    num_per_shard = int(len(filenames) / _NUM_SHARDS)
    print('split_name:', split_name)
    print('num_per_shard', num_per_shard)
    with tf.Graph().as_default():
        with tf.Session() as sess:
            for shard_id in range(_NUM_SHARDS):
                # 定义tfrecord文件的路径和名字
                output_filename = _get_dataset_filename(dataset_dir, split_name, shard_id)
                
                with tf.python_io.TFRecordWriter(output_filename) as tfrecord_writer:
                    # 每一个数据块开始的位置
                    start_ndx = shard_id * num_per_shard
                    # 每一个数据块最后的位置
                    end_ndx = min((shard_id + 1) * num_per_shard, len(filenames))
                    for i in range(start_ndx, end_ndx):
                        try:
                            sys.stdout.write('\r>> Converting image %d/%d shard %d' % (i+1, len(filenames), shard_id))
                            sys.stdout.flush()
                            # 读取图片
                            image_data = tf.gfile.GFile(filenames[i], 'rb').read()
                            # 获得图片的类别名称
                            class_name = os.path.basename(os.path.dirname(filenames[i]))
                            # 找到类别名称对应的id
                            class_id = class_names_to_ids[class_name]
                            print('>>>',class_id, class_name)
                            
                            # 生成tfrecord文件
                            example = image_to_tfexample(image_data, b'jpg', class_id)
                            tfrecord_writer.write(example.SerializeToString())
                        except IOError as e:
                            print('Could not read:', filenames[i])
                            print('Error:', e)
                            print('Skip it \n')
    sys.stdout.write('\n')
    sys.stdout.flush()

# %%
if __name__=='__main__':
    # 判断tfrecord文件是否存在
    if _dataset_exists(DATASET_DIR):
        print('tfrecord文件已存在')
    else:
        print('tfrecord文件不存在，开始构建...')
        # 获得所有图片以及分类
        photo_filenames, class_names = _get_filenames_and_classes(DATASET_DIR)
        
        # 将分类转换为字典格式，类似于{'birds': 0, 'faces': 1, 'flower': 2, 'horse': 3}
        class_names_to_ids = dict(zip(class_names, range(len(class_names))))
        print(class_names_to_ids)
                                  
        # 将数据切分成训练集和测试集
        random.seed(_RANDOM_SEED)
        random.shuffle(photo_filenames)
        training_filenames = photo_filenames[_NUM_TEST: ]
        testing_filenames = photo_filenames[: _NUM_TEST]
        
        # 数据转换
        _convert_dataset('train', training_filenames, class_names_to_ids, DATASET_DIR)
        _convert_dataset('test', testing_filenames, class_names_to_ids, DATASET_DIR)
        
        # 输出labels文件
        labels_to_class_names = dict(zip(range(len(class_names)), class_names))
        write_label_file(labels_to_class_names, DATASET_DIR)
# Out:
# tfrecord文件不存在，开始构建...
# {'flower': 0, 'birds': 1, 'horse': 2, 'faces': 3}
# split_name: train
# num_per_shard 3621
# >> Converting image 1/14486 shard 0>>> 0 flower
# >> Converting image 2/14486 shard 0>>> 1 birds
# >> Converting image 3/14486 shard 0>>> 0 flower
# >> Converting image 4/14486 shard 0>>> 0 flower
# >> Converting image 5/14486 shard 0>>> 3 faces
# >> Converting image 6/14486 shard 0>>> 1 birds
# >> Converting image 7/14486 shard 0>>> 0 flower
# >> Converting image 8/14486 shard 0>>> 1 birds
# >> Converting image 9/14486 shard 0>>> 3 faces
# >> Converting image 10/14486 shard 0>>> 0 flower
# >> Converting image 11/14486 shard 0>>> 0 flower
# >> Converting image 12/14486 shard 0>>> 0 flower
# >> Converting image 13/14486 shard 0>>> 1 birds
# >> Converting image 14/14486 shard 0>>> 3 faces
# >> Converting image 15/14486 shard 0>>> 1 birds
# >> Converting image 16/14486 shard 0>>> 1 birds
# >> Converting image 17/14486 shard 0>>> 2 horse
# >> Converting image 18/14486 shard 0>>> 3 faces
# >> Converting image 19/14486 shard 0>>> 1 birds
# >> Converting image 20/14486 shard 0>>> 1 birds
# >> Converting image 21/14486 shard 0>>> 0 flower
# >> Converting image 22/14486 shard 0>>> 1 birds
# >> Converting image 23/14486 shard 0>>> 1 birds
# >> Converting image 24/14486 shard 0>>> 1 birds
# >> Converting image 25/14486 shard 0>>> 0 flower
# >> Converting image 26/14486 shard 0>>> 1 birds
# >> Converting image 27/14486 shard 0>>> 1 birds
# >> Converting image 28/14486 shard 0>>> 1 birds
# >> Converting image 29/14486 shard 0>>> 1 birds
# >> Converting image 30/14486 shard 0>>> 0 flower
# >> Converting image 31/14486 shard 0>>> 0 flower
# >> Converting image 32/14486 shard 0>>> 0 flower
# >> Converting image 33/14486 shard 0>>> 0 flower
# >> Converting image 34/14486 shard 0>>> 1 birds
# >> Converting image 35/14486 shard 0>>> 0 flower
# >> Converting image 36/14486 shard 0>>> 0 flower
# >> Converting image 37/14486 shard 0>>> 0 flower
# >> Converting image 38/14486 shard 0>>> 0 flower
# >> Converting image 39/14486 shard 0>>> 1 birds
# >> Converting image 40/14486 shard 0>>> 0 flower
# >> Converting image 41/14486 shard 0>>> 1 birds
# >> Converting image 42/14486 shard 0>>> 1 birds
# >> Converting image 43/14486 shard 0>>> 0 flower
# >> Converting image 44/14486 shard 0>>> 1 birds
# >> Converting image 45/14486 shard 0>>> 2 horse
# >> Converting image 46/14486 shard 0>>> 1 birds
# >> Converting image 47/14486 shard 0>>> 0 flower
# >> Converting image 48/14486 shard 0>>> 0 flower
# >> Converting image 49/14486 shard 0>>> 0 flower
# >> Converting image 50/14486 shard 0>>> 1 birds
# >> Converting image 51/14486 shard 0>>> 0 flower
# >> Converting image 52/14486 shard 0>>> 1 birds
# >> Converting image 53/14486 shard 0>>> 0 flower
# >> Converting image 54/14486 shard 0>>> 1 birds
# >> Converting image 55/14486 shard 0>>> 1 birds
# >> Converting image 56/14486 shard 0>>> 1 birds
# >> Converting image 57/14486 shard 0>>> 0 flower
# >> Converting image 58/14486 shard 0>>> 0 flower
# >> Converting image 59/14486 shard 0>>> 0 flower
# >> Converting image 60/14486 shard 0>>> 0 flower
# >> Converting image 61/14486 shard 0>>> 0 flower
# >> Converting image 62/14486 shard 0>>> 1 birds
# >> Converting image 63/14486 shard 0>>> 3 faces
# >> Converting image 64/14486 shard 0>>> 1 birds
# >> Converting image 65/14486 shard 0>>> 1 birds
# >> Converting image 66/14486 shard 0>>> 1 birds
# >> Converting image 67/14486 shard 0>>> 0 flower
# >> Converting image 68/14486 shard 0>>> 0 flower
# >> Converting image 69/14486 shard 0>>> 0 flower
# >> Converting image 70/14486 shard 0>>> 0 flower
# >> Converting image 71/14486 shard 0>>> 1 birds
# >> Converting image 72/14486 shard 0>>> 1 birds
# >> Converting image 73/14486 shard 0>>> 0 flower
# >> Converting image 74/14486 shard 0>>> 0 flower
# >> Converting image 75/14486 shard 0>>> 0 flower
# >> Converting image 76/14486 shard 0>>> 0 flower
# >> Converting image 77/14486 shard 0>>> 0 flower
# >> Converting image 78/14486 shard 0>>> 0 flower
# >> Converting image 79/14486 shard 0>>> 0 flower
# >> Converting image 80/14486 shard 0>>> 0 flower
# >> Converting image 81/14486 shard 0>>> 0 flower
# >> Converting image 82/14486 shard 0>>> 0 flower
# >> Converting image 83/14486 shard 0>>> 1 birds
# >> Converting image 84/14486 shard 0>>> 0 flower
# >> Converting image 85/14486 shard 0>>> 1 birds
# >> Converting image 86/14486 shard 0>>> 0 flower
# >> Converting image 87/14486 shard 0>>> 0 flower
# >> Converting image 88/14486 shard 0>>> 1 birds
# >> Converting image 89/14486 shard 0>>> 1 birds
# >> Converting image 90/14486 shard 0>>> 0 flower
# >> Converting image 91/14486 shard 0>>> 3 faces
# >> Converting image 92/14486 shard 0>>> 0 flower
# >> Converting image 93/14486 shard 0>>> 0 flower
# >> Converting image 94/14486 shard 0>>> 0 flower
# >> Converting image 95/14486 shard 0>>> 1 birds
# >> Converting image 96/14486 shard 0>>> 1 birds
# >> Converting image 97/14486 shard 0>>> 0 flower
# >> Converting image 98/14486 shard 0>>> 0 flower
# >> Converting image 99/14486 shard 0>>> 0 flower
# >> Converting image 100/14486 shard 0>>> 0 flower
# >> Converting image 101/14486 shard 0>>> 1 birds
# >> Converting image 102/14486 shard 0>>> 0 flower
# >> Converting image 103/14486 shard 0>>> 0 flower
# >> Converting image 104/14486 shard 0>>> 0 flower
# >> Converting image 105/14486 shard 0>>> 0 flower
# >> Converting image 106/14486 shard 0>>> 0 flower
# >> Converting image 107/14486 shard 0>>> 0 flower
# >> Converting image 108/14486 shard 0>>> 1 birds
# >> Converting image 109/14486 shard 0>>> 0 flower
# >> Converting image 110/14486 shard 0>>> 0 flower
# >> Converting image 111/14486 shard 0>>> 0 flower
# >> Converting image 112/14486 shard 0>>> 0 flower
# >> Converting image 113/14486 shard 0>>> 1 birds
# >> Converting image 114/14486 shard 0>>> 2 horse
# >> Converting image 115/14486 shard 0>>> 2 horse
# >> Converting image 116/14486 shard 0>>> 3 faces
# >> Converting image 117/14486 shard 0>>> 1 birds
# >> Converting image 118/14486 shard 0>>> 0 flower
# >> Converting image 119/14486 shard 0>>> 1 birds
# >> Converting image 120/14486 shard 0>>> 0 flower
# >> Converting image 121/14486 shard 0>>> 1 birds
# >> Converting image 122/14486 shard 0>>> 1 birds
# >> Converting image 123/14486 shard 0>>> 0 flower
# >> Converting image 124/14486 shard 0>>> 0 flower
# >> Converting image 125/14486 shard 0>>> 0 flower
# >> Converting image 126/14486 shard 0>>> 1 birds
# >> Converting image 127/14486 shard 0>>> 1 birds
# >> Converting image 128/14486 shard 0>>> 0 flower
# >> Converting image 129/14486 shard 0>>> 0 flower
# >> Converting image 130/14486 shard 0>>> 0 flower
# >> Converting image 131/14486 shard 0>>> 0 flower
# >> Converting image 132/14486 shard 0>>> 1 birds
# >> Converting image 133/14486 shard 0>>> 0 flower
# >> Converting image 134/14486 shard 0>>> 1 birds
# >> Converting image 135/14486 shard 0>>> 0 flower
# >> Converting image 136/14486 shard 0>>> 0 flower
# >> Converting image 137/14486 shard 0>>> 0 flower
# >> Converting image 138/14486 shard 0>>> 1 birds
# >> Converting image 139/14486 shard 0>>> 0 flower
# >> Converting image 140/14486 shard 0>>> 1 birds
# >> Converting image 141/14486 shard 0>>> 1 birds
# >> Converting image 142/14486 shard 0>>> 1 birds
# >> Converting image 143/14486 shard 0>>> 0 flower
# >> Converting image 144/14486 shard 0>>> 0 flower
# >> Converting image 145/14486 shard 0>>> 1 birds
# >> Converting image 146/14486 shard 0>>> 0 flower
# >> Converting image 147/14486 shard 0>>> 0 flower
# >> Converting image 148/14486 shard 0>>> 0 flower
# >> Converting image 149/14486 shard 0>>> 0 flower
# >> Converting image 150/14486 shard 0>>> 0 flower
# >> Converting image 151/14486 shard 0>>> 1 birds
# >> Converting image 152/14486 shard 0>>> 0 flower
# >> Converting image 153/14486 shard 0>>> 1 birds
# >> Converting image 154/14486 shard 0>>> 1 birds
# >> Converting image 155/14486 shard 0>>> 1 birds
# >> Converting image 156/14486 shard 0>>> 1 birds
# >> Converting image 157/14486 shard 0>>> 0 flower
# >> Converting image 158/14486 shard 0>>> 1 birds
# >> Converting image 159/14486 shard 0>>> 0 flower
# >> Converting image 160/14486 shard 0>>> 0 flower
# >> Converting image 161/14486 shard 0>>> 0 flower
# >> Converting image 162/14486 shard 0>>> 1 birds
# >> Converting image 163/14486 shard 0>>> 3 faces
# >> Converting image 164/14486 shard 0>>> 1 birds
# >> Converting image 165/14486 shard 0>>> 1 birds
# >> Converting image 166/14486 shard 0>>> 1 birds
# >> Converting image 167/14486 shard 0>>> 0 flower
# >> Converting image 168/14486 shard 0>>> 1 birds
# >> Converting image 169/14486 shard 0>>> 0 flower
# >> Converting image 170/14486 shard 0>>> 0 flower
# >> Converting image 171/14486 shard 0>>> 1 birds
# >> Converting image 172/14486 shard 0>>> 0 flower
# >> Converting image 173/14486 shard 0>>> 1 birds
# >> Converting image 174/14486 shard 0>>> 1 birds
# >> Converting image 175/14486 shard 0>>> 0 flower
# >> Converting image 176/14486 shard 0>>> 1 birds
# >> Converting image 177/14486 shard 0>>> 0 flower
# >> Converting image 178/14486 shard 0>>> 0 flower
# >> Converting image 179/14486 shard 0>>> 0 flower
# >> Converting image 180/14486 shard 0>>> 0 flower
# >> Converting image 181/14486 shard 0>>> 0 flower
# >> Converting image 182/14486 shard 0>>> 1 birds
# >> Converting image 183/14486 shard 0>>> 1 birds
# >> Converting image 184/14486 shard 0>>> 1 birds
# >> Converting image 185/14486 shard 0>>> 0 flower
# >> Converting image 186/14486 shard 0>>> 0 flower
# >> Converting image 187/14486 shard 0>>> 0 flower
# >> Converting image 188/14486 shard 0>>> 0 flower
# >> Converting image 189/14486 shard 0>>> 0 flower
# >> Converting image 190/14486 shard 0>>> 1 birds
# >> Converting image 191/14486 shard 0>>> 0 flower
# >> Converting image 192/14486 shard 0>>> 1 birds
# >> Converting image 193/14486 shard 0>>> 1 birds
# >> Converting image 194/14486 shard 0>>> 0 flower
# >> Converting image 195/14486 shard 0>>> 1 birds
# >> Converting image 196/14486 shard 0>>> 1 birds
# >> Converting image 197/14486 shard 0>>> 0 flower
# >> Converting image 198/14486 shard 0>>> 0 flower
# >> Converting image 199/14486 shard 0>>> 0 flower
# >> Converting image 200/14486 shard 0>>> 0 flower
# >> Converting image 201/14486 shard 0>>> 0 flower
# >> Converting image 202/14486 shard 0>>> 1 birds
# >> Converting image 203/14486 shard 0>>> 0 flower
# >> Converting image 204/14486 shard 0>>> 0 flower
# >> Converting image 205/14486 shard 0>>> 1 birds
# >> Converting image 206/14486 shard 0>>> 1 birds
# >> Converting image 207/14486 shard 0>>> 1 birds
# >> Converting image 208/14486 shard 0>>> 0 flower
# >> Converting image 209/14486 shard 0>>> 0 flower
# >> Converting image 210/14486 shard 0>>> 1 birds
# >> Converting image 211/14486 shard 0>>> 1 birds
# >> Converting image 212/14486 shard 0>>> 1 birds
# >> Converting image 213/14486 shard 0>>> 0 flower
# >> Converting image 214/14486 shard 0>>> 0 flower
# >> Converting image 215/14486 shard 0>>> 0 flower
# >> Converting image 216/14486 shard 0>>> 0 flower
# >> Converting image 217/14486 shard 0>>> 0 flower
# >> Converting image 218/14486 shard 0>>> 0 flower
# >> Converting image 219/14486 shard 0>>> 1 birds
# >> Converting image 220/14486 shard 0>>> 0 flower
# >> Converting image 221/14486 shard 0>>> 1 birds
# >> Converting image 222/14486 shard 0>>> 1 birds
# >> Converting image 223/14486 shard 0>>> 1 birds
# >> Converting image 224/14486 shard 0>>> 1 birds
# >> Converting image 225/14486 shard 0>>> 3 faces
# >> Converting image 226/14486 shard 0>>> 1 birds
# >> Converting image 227/14486 shard 0>>> 0 flower
# >> Converting image 228/14486 shard 0>>> 0 flower
# >> Converting image 229/14486 shard 0>>> 0 flower
# >> Converting image 230/14486 shard 0>>> 1 birds
# >> Converting image 231/14486 shard 0>>> 0 flower
# >> Converting image 232/14486 shard 0>>> 0 flower
# >> Converting image 233/14486 shard 0>>> 0 flower
# >> Converting image 234/14486 shard 0>>> 3 faces
# >> Converting image 235/14486 shard 0>>> 0 flower
# >> Converting image 236/14486 shard 0>>> 0 flower
# >> Converting image 237/14486 shard 0>>> 0 flower
# >> Converting image 238/14486 shard 0>>> 1 birds
# >> Converting image 239/14486 shard 0>>> 0 flower
# >> Converting image 240/14486 shard 0>>> 0 flower
# >> Converting image 241/14486 shard 0>>> 1 birds
# >> Converting image 242/14486 shard 0>>> 0 flower
# >> Converting image 243/14486 shard 0>>> 0 flower
# >> Converting image 244/14486 shard 0>>> 0 flower
# >> Converting image 245/14486 shard 0>>> 0 flower
# >> Converting image 246/14486 shard 0>>> 0 flower
# >> Converting image 247/14486 shard 0>>> 1 birds
# >> Converting image 248/14486 shard 0>>> 0 flower
# >> Converting image 249/14486 shard 0>>> 1 birds
# >> Converting image 250/14486 shard 0>>> 0 flower
# >> Converting image 251/14486 shard 0>>> 1 birds
# >> Converting image 252/14486 shard 0>>> 1 birds
# >> Converting image 253/14486 shard 0>>> 0 flower
# >> Converting image 254/14486 shard 0>>> 0 flower
# >> Converting image 255/14486 shard 0>>> 0 flower
# >> Converting image 256/14486 shard 0>>> 0 flower
# >> Converting image 257/14486 shard 0>>> 0 flower
# >> Converting image 258/14486 shard 0>>> 0 flower
# >> Converting image 259/14486 shard 0>>> 0 flower
# >> Converting image 260/14486 shard 0>>> 2 horse
# >> Converting image 261/14486 shard 0>>> 0 flower
# >> Converting image 262/14486 shard 0>>> 1 birds
# >> Converting image 263/14486 shard 0>>> 0 flower
# >> Converting image 264/14486 shard 0>>> 0 flower
# >> Converting image 265/14486 shard 0>>> 0 flower
# >> Converting image 266/14486 shard 0>>> 0 flower
# >> Converting image 267/14486 shard 0>>> 0 flower
# >> Converting image 268/14486 shard 0>>> 1 birds
# >> Converting image 269/14486 shard 0>>> 0 flower
# >> Converting image 270/14486 shard 0>>> 0 flower
# >> Converting image 271/14486 shard 0>>> 0 flower
# >> Converting image 272/14486 shard 0>>> 1 birds
# >> Converting image 273/14486 shard 0>>> 0 flower
# >> Converting image 274/14486 shard 0>>> 0 flower
# >> Converting image 275/14486 shard 0>>> 0 flower
# >> Converting image 276/14486 shard 0>>> 1 birds
# >> Converting image 277/14486 shard 0>>> 1 birds
# >> Converting image 278/14486 shard 0>>> 0 flower
# >> Converting image 279/14486 shard 0>>> 0 flower
# >> Converting image 280/14486 shard 0>>> 1 birds
# >> Converting image 281/14486 shard 0>>> 0 flower
# >> Converting image 282/14486 shard 0>>> 0 flower
# >> Converting image 283/14486 shard 0>>> 1 birds
# >> Converting image 284/14486 shard 0>>> 1 birds
# >> Converting image 285/14486 shard 0>>> 1 birds
# >> Converting image 286/14486 shard 0>>> 0 flower
# >> Converting image 287/14486 shard 0>>> 0 flower
# >> Converting image 288/14486 shard 0>>> 1 birds
# >> Converting image 289/14486 shard 0>>> 0 flower
# >> Converting image 290/14486 shard 0>>> 0 flower
# >> Converting image 291/14486 shard 0>>> 1 birds
# >> Converting image 292/14486 shard 0>>> 0 flower
# >> Converting image 293/14486 shard 0>>> 1 birds
# >> Converting image 294/14486 shard 0>>> 0 flower
# >> Converting image 295/14486 shard 0>>> 1 birds
# >> Converting image 296/14486 shard 0>>> 1 birds
# >> Converting image 297/14486 shard 0>>> 1 birds
# >> Converting image 298/14486 shard 0>>> 1 birds
# >> Converting image 299/14486 shard 0>>> 0 flower
# >> Converting image 300/14486 shard 0>>> 1 birds
# >> Converting image 301/14486 shard 0>>> 0 flower
# >> Converting image 302/14486 shard 0>>> 0 flower
# >> Converting image 303/14486 shard 0>>> 1 birds
# >> Converting image 304/14486 shard 0>>> 0 flower
# >> Converting image 305/14486 shard 0>>> 1 birds
# >> Converting image 306/14486 shard 0>>> 0 flower
# >> Converting image 307/14486 shard 0>>> 0 flower
# >> Converting image 308/14486 shard 0>>> 0 flower
# >> Converting image 309/14486 shard 0>>> 1 birds
# >> Converting image 310/14486 shard 0>>> 0 flower
# >> Converting image 311/14486 shard 0>>> 0 flower
# >> Converting image 312/14486 shard 0>>> 0 flower
# >> Converting image 313/14486 shard 0>>> 0 flower
# >> Converting image 314/14486 shard 0>>> 0 flower
# >> Converting image 315/14486 shard 0>>> 0 flower
# >> Converting image 316/14486 shard 0>>> 0 flower
# >> Converting image 317/14486 shard 0>>> 0 flower
# >> Converting image 318/14486 shard 0>>> 0 flower
# >> Converting image 319/14486 shard 0>>> 1 birds
# >> Converting image 320/14486 shard 0>>> 1 birds
# >> Converting image 321/14486 shard 0>>> 0 flower
# >> Converting image 322/14486 shard 0>>> 0 flower
# >> Converting image 323/14486 shard 0>>> 0 flower
# >> Converting image 324/14486 shard 0>>> 0 flower
# >> Converting image 325/14486 shard 0>>> 0 flower
# >> Converting image 326/14486 shard 0>>> 1 birds
# >> Converting image 327/14486 shard 0>>> 0 flower
# >> Converting image 328/14486 shard 0>>> 0 flower
# >> Converting image 329/14486 shard 0>>> 2 horse
# >> Converting image 330/14486 shard 0>>> 0 flower
# >> Converting image 331/14486 shard 0>>> 1 birds
# >> Converting image 332/14486 shard 0>>> 1 birds
# >> Converting image 333/14486 shard 0>>> 1 birds
# >> Converting image 334/14486 shard 0>>> 1 birds
# >> Converting image 335/14486 shard 0>>> 2 horse
# >> Converting image 336/14486 shard 0>>> 1 birds
# >> Converting image 337/14486 shard 0>>> 1 birds
# >> Converting image 338/14486 shard 0>>> 0 flower
# >> Converting image 339/14486 shard 0>>> 0 flower
# >> Converting image 340/14486 shard 0>>> 0 flower
# >> Converting image 341/14486 shard 0>>> 1 birds
# >> Converting image 342/14486 shard 0>>> 0 flower
# >> Converting image 343/14486 shard 0>>> 1 birds
# >> Converting image 344/14486 shard 0>>> 0 flower
# >> Converting image 345/14486 shard 0>>> 1 birds
# >> Converting image 346/14486 shard 0>>> 0 flower
# >> Converting image 347/14486 shard 0>>> 0 flower
# >> Converting image 348/14486 shard 0>>> 0 flower
# >> Converting image 349/14486 shard 0>>> 0 flower
# >> Converting image 350/14486 shard 0>>> 0 flower
# >> Converting image 351/14486 shard 0>>> 0 flower
# >> Converting image 352/14486 shard 0>>> 0 flower
# >> Converting image 353/14486 shard 0>>> 1 birds
# >> Converting image 354/14486 shard 0>>> 2 horse
# >> Converting image 355/14486 shard 0>>> 0 flower
# >> Converting image 356/14486 shard 0>>> 1 birds
# >> Converting image 357/14486 shard 0>>> 0 flower
# >> Converting image 358/14486 shard 0>>> 0 flower
# >> Converting image 359/14486 shard 0>>> 1 birds
# >> Converting image 360/14486 shard 0>>> 1 birds
# >> Converting image 361/14486 shard 0>>> 1 birds
# >> Converting image 362/14486 shard 0>>> 1 birds
# >> Converting image 363/14486 shard 0>>> 1 birds
# >> Converting image 364/14486 shard 0>>> 2 horse
# >> Converting image 365/14486 shard 0>>> 1 birds
# >> Converting image 366/14486 shard 0>>> 0 flower
# >> Converting image 367/14486 shard 0>>> 0 flower
# >> Converting image 368/14486 shard 0>>> 1 birds
# >> Converting image 369/14486 shard 0>>> 1 birds
# >> Converting image 370/14486 shard 0>>> 0 flower
# >> Converting image 371/14486 shard 0>>> 1 birds
# >> Converting image 372/14486 shard 0>>> 0 flower
# >> Converting image 373/14486 shard 0>>> 0 flower
# >> Converting image 374/14486 shard 0>>> 0 flower
# >> Converting image 375/14486 shard 0>>> 1 birds
# >> Converting image 376/14486 shard 0>>> 0 flower
# >> Converting image 377/14486 shard 0>>> 0 flower
# >> Converting image 378/14486 shard 0>>> 1 birds
# >> Converting image 379/14486 shard 0>>> 0 flower
# >> Converting image 380/14486 shard 0>>> 1 birds
# >> Converting image 381/14486 shard 0>>> 0 flower
# >> Converting image 382/14486 shard 0>>> 1 birds
# >> Converting image 383/14486 shard 0>>> 1 birds
# >> Converting image 384/14486 shard 0>>> 1 birds
# >> Converting image 385/14486 shard 0>>> 2 horse
# >> Converting image 386/14486 shard 0>>> 1 birds
# >> Converting image 387/14486 shard 0>>> 0 flower
# >> Converting image 388/14486 shard 0>>> 0 flower
# >> Converting image 389/14486 shard 0>>> 1 birds
# >> Converting image 390/14486 shard 0>>> 1 birds
# >> Converting image 391/14486 shard 0>>> 0 flower
# >> Converting image 392/14486 shard 0>>> 0 flower
# >> Converting image 393/14486 shard 0>>> 1 birds
# >> Converting image 394/14486 shard 0>>> 0 flower
# >> Converting image 395/14486 shard 0>>> 0 flower
# >> Converting image 396/14486 shard 0>>> 1 birds
# >> Converting image 397/14486 shard 0>>> 1 birds
# >> Converting image 398/14486 shard 0>>> 1 birds
# >> Converting image 399/14486 shard 0>>> 0 flower
# >> Converting image 400/14486 shard 0>>> 0 flower
# >> Converting image 401/14486 shard 0>>> 0 flower
# >> Converting image 402/14486 shard 0>>> 0 flower
# >> Converting image 403/14486 shard 0>>> 1 birds
# >> Converting image 404/14486 shard 0>>> 1 birds
# >> Converting image 405/14486 shard 0>>> 2 horse
# >> Converting image 406/14486 shard 0>>> 0 flower
# >> Converting image 407/14486 shard 0>>> 3 faces
# >> Converting image 408/14486 shard 0>>> 1 birds
# >> Converting image 409/14486 shard 0>>> 0 flower
# >> Converting image 410/14486 shard 0>>> 0 flower
# >> Converting image 411/14486 shard 0>>> 1 birds
# >> Converting image 412/14486 shard 0>>> 0 flower
# >> Converting image 413/14486 shard 0>>> 0 flower
# >> Converting image 414/14486 shard 0>>> 0 flower
# >> Converting image 415/14486 shard 0>>> 0 flower
# >> Converting image 416/14486 shard 0>>> 0 flower
# >> Converting image 417/14486 shard 0>>> 0 flower
# >> Converting image 418/14486 shard 0>>> 0 flower
# >> Converting image 419/14486 shard 0>>> 1 birds
# >> Converting image 420/14486 shard 0>>> 0 flower
# >> Converting image 421/14486 shard 0>>> 0 flower
# >> Converting image 422/14486 shard 0>>> 0 flower
# >> Converting image 423/14486 shard 0>>> 1 birds
# >> Converting image 424/14486 shard 0>>> 0 flower
# >> Converting image 425/14486 shard 0>>> 0 flower
# >> Converting image 426/14486 shard 0>>> 1 birds
# >> Converting image 427/14486 shard 0>>> 1 birds
# >> Converting image 428/14486 shard 0>>> 0 flower
# >> Converting image 429/14486 shard 0>>> 1 birds
# >> Converting image 430/14486 shard 0>>> 0 flower
# >> Converting image 431/14486 shard 0>>> 1 birds
# >> Converting image 432/14486 shard 0>>> 1 birds
# >> Converting image 433/14486 shard 0>>> 1 birds
# >> Converting image 434/14486 shard 0>>> 0 flower
# >> Converting image 435/14486 shard 0>>> 1 birds
# >> Converting image 436/14486 shard 0>>> 1 birds
# >> Converting image 437/14486 shard 0>>> 2 horse
# >> Converting image 438/14486 shard 0>>> 0 flower
# >> Converting image 439/14486 shard 0>>> 0 flower
# >> Converting image 440/14486 shard 0>>> 1 birds
# >> Converting image 441/14486 shard 0>>> 1 birds
# >> Converting image 442/14486 shard 0>>> 1 birds
# >> Converting image 443/14486 shard 0>>> 0 flower
# >> Converting image 444/14486 shard 0>>> 1 birds
# >> Converting image 445/14486 shard 0>>> 0 flower
# >> Converting image 446/14486 shard 0>>> 0 flower
# >> Converting image 447/14486 shard 0>>> 1 birds
# >> Converting image 448/14486 shard 0>>> 1 birds
# >> Converting image 449/14486 shard 0>>> 1 birds
# >> Converting image 450/14486 shard 0>>> 1 birds
# >> Converting image 451/14486 shard 0>>> 1 birds
# >> Converting image 452/14486 shard 0>>> 1 birds
# >> Converting image 453/14486 shard 0>>> 1 birds
# >> Converting image 454/14486 shard 0>>> 2 horse
# >> Converting image 455/14486 shard 0>>> 0 flower
# >> Converting image 456/14486 shard 0>>> 1 birds
# >> Converting image 457/14486 shard 0>>> 1 birds
# >> Converting image 458/14486 shard 0>>> 0 flower
# >> Converting image 459/14486 shard 0>>> 0 flower
# >> Converting image 460/14486 shard 0>>> 0 flower
# >> Converting image 461/14486 shard 0>>> 0 flower
# >> Converting image 462/14486 shard 0>>> 3 faces
# >> Converting image 463/14486 shard 0>>> 0 flower
# >> Converting image 464/14486 shard 0>>> 3 faces
# >> Converting image 465/14486 shard 0>>> 0 flower
# >> Converting image 466/14486 shard 0>>> 0 flower
# >> Converting image 467/14486 shard 0>>> 1 birds
# >> Converting image 468/14486 shard 0>>> 0 flower
# >> Converting image 469/14486 shard 0>>> 0 flower
# >> Converting image 470/14486 shard 0>>> 0 flower
# >> Converting image 471/14486 shard 0>>> 0 flower
# >> Converting image 472/14486 shard 0>>> 3 faces
# >> Converting image 473/14486 shard 0>>> 0 flower
# >> Converting image 474/14486 shard 0>>> 0 flower
# >> Converting image 475/14486 shard 0>>> 1 birds
# >> Converting image 476/14486 shard 0>>> 2 horse
# >> Converting image 477/14486 shard 0>>> 0 flower
# >> Converting image 478/14486 shard 0>>> 0 flower
# >> Converting image 479/14486 shard 0>>> 0 flower
# >> Converting image 480/14486 shard 0>>> 0 flower
# >> Converting image 481/14486 shard 0>>> 1 birds
# >> Converting image 482/14486 shard 0>>> 1 birds
# >> Converting image 483/14486 shard 0>>> 0 flower
# >> Converting image 484/14486 shard 0>>> 1 birds
# >> Converting image 485/14486 shard 0>>> 1 birds
# >> Converting image 486/14486 shard 0>>> 1 birds
# >> Converting image 487/14486 shard 0>>> 0 flower
# >> Converting image 488/14486 shard 0>>> 1 birds
# >> Converting image 489/14486 shard 0>>> 0 flower
# >> Converting image 490/14486 shard 0>>> 1 birds
# >> Converting image 491/14486 shard 0>>> 3 faces
# >> Converting image 492/14486 shard 0>>> 0 flower
# >> Converting image 493/14486 shard 0>>> 1 birds
# >> Converting image 494/14486 shard 0>>> 0 flower
# >> Converting image 495/14486 shard 0>>> 0 flower
# >> Converting image 496/14486 shard 0>>> 1 birds
# >> Converting image 497/14486 shard 0>>> 1 birds
# >> Converting image 498/14486 shard 0>>> 1 birds
# >> Converting image 499/14486 shard 0>>> 1 birds
# >> Converting image 500/14486 shard 0>>> 1 birds
# >> Converting image 501/14486 shard 0>>> 0 flower
# >> Converting image 502/14486 shard 0>>> 0 flower
# >> Converting image 503/14486 shard 0>>> 1 birds
# >> Converting image 504/14486 shard 0>>> 1 birds
# >> Converting image 505/14486 shard 0>>> 0 flower
# >> Converting image 506/14486 shard 0>>> 1 birds
# >> Converting image 507/14486 shard 0>>> 1 birds
# >> Converting image 508/14486 shard 0>>> 0 flower
# >> Converting image 509/14486 shard 0>>> 1 birds
# >> Converting image 510/14486 shard 0>>> 0 flower
# >> Converting image 511/14486 shard 0>>> 0 flower
# >> Converting image 512/14486 shard 0>>> 0 flower
# >> Converting image 513/14486 shard 0>>> 1 birds
# >> Converting image 514/14486 shard 0>>> 0 flower
# >> Converting image 515/14486 shard 0>>> 0 flower
# >> Converting image 516/14486 shard 0>>> 1 birds
# >> Converting image 517/14486 shard 0>>> 0 flower
# >> Converting image 518/14486 shard 0>>> 3 faces
# >> Converting image 519/14486 shard 0>>> 0 flower
# >> Converting image 520/14486 shard 0>>> 1 birds
# >> Converting image 521/14486 shard 0>>> 1 birds
# >> Converting image 522/14486 shard 0>>> 3 faces
# >> Converting image 523/14486 shard 0>>> 0 flower
# >> Converting image 524/14486 shard 0>>> 0 flower
# >> Converting image 525/14486 shard 0>>> 0 flower
# >> Converting image 526/14486 shard 0>>> 1 birds
# >> Converting image 527/14486 shard 0>>> 0 flower
# >> Converting image 528/14486 shard 0>>> 1 birds
# >> Converting image 529/14486 shard 0>>> 1 birds
# >> Converting image 530/14486 shard 0>>> 1 birds
# >> Converting image 531/14486 shard 0>>> 0 flower
# >> Converting image 532/14486 shard 0>>> 0 flower
# >> Converting image 533/14486 shard 0>>> 0 flower
# >> Converting image 534/14486 shard 0>>> 3 faces
# >> Converting image 535/14486 shard 0>>> 1 birds
# >> Converting image 536/14486 shard 0>>> 0 flower
# >> Converting image 537/14486 shard 0>>> 0 flower
# >> Converting image 538/14486 shard 0>>> 0 flower
# >> Converting image 539/14486 shard 0>>> 0 flower
# >> Converting image 540/14486 shard 0>>> 1 birds
# >> Converting image 541/14486 shard 0>>> 1 birds
# >> Converting image 542/14486 shard 0>>> 1 birds
# >> Converting image 543/14486 shard 0>>> 0 flower
# >> Converting image 544/14486 shard 0>>> 0 flower
# >> Converting image 545/14486 shard 0>>> 0 flower
# >> Converting image 546/14486 shard 0>>> 0 flower
# >> Converting image 547/14486 shard 0>>> 1 birds
# >> Converting image 548/14486 shard 0>>> 0 flower
# >> Converting image 549/14486 shard 0>>> 1 birds
# >> Converting image 550/14486 shard 0>>> 2 horse
# >> Converting image 551/14486 shard 0>>> 1 birds
# >> Converting image 552/14486 shard 0>>> 0 flower
# >> Converting image 553/14486 shard 0>>> 0 flower
# >> Converting image 554/14486 shard 0>>> 1 birds
# >> Converting image 555/14486 shard 0>>> 0 flower
# >> Converting image 556/14486 shard 0>>> 1 birds
# >> Converting image 557/14486 shard 0>>> 1 birds
# >> Converting image 558/14486 shard 0>>> 0 flower
# >> Converting image 559/14486 shard 0>>> 0 flower
# >> Converting image 560/14486 shard 0>>> 0 flower
# >> Converting image 561/14486 shard 0>>> 0 flower
# >> Converting image 562/14486 shard 0>>> 1 birds
# >> Converting image 563/14486 shard 0>>> 1 birds
# >> Converting image 564/14486 shard 0>>> 0 flower
# >> Converting image 565/14486 shard 0>>> 0 flower
# >> Converting image 566/14486 shard 0>>> 1 birds
# >> Converting image 567/14486 shard 0>>> 0 flower
# >> Converting image 568/14486 shard 0>>> 0 flower
# >> Converting image 569/14486 shard 0>>> 0 flower
# >> Converting image 570/14486 shard 0>>> 0 flower
# >> Converting image 571/14486 shard 0>>> 0 flower
# >> Converting image 572/14486 shard 0>>> 0 flower
# >> Converting image 573/14486 shard 0>>> 1 birds
# >> Converting image 574/14486 shard 0>>> 1 birds
# >> Converting image 575/14486 shard 0>>> 1 birds
# >> Converting image 576/14486 shard 0>>> 1 birds
# >> Converting image 577/14486 shard 0>>> 0 flower
# >> Converting image 578/14486 shard 0>>> 0 flower
# >> Converting image 579/14486 shard 0>>> 0 flower
# >> Converting image 580/14486 shard 0>>> 0 flower
# >> Converting image 581/14486 shard 0>>> 1 birds
# >> Converting image 582/14486 shard 0>>> 0 flower
# >> Converting image 583/14486 shard 0>>> 3 faces
# >> Converting image 584/14486 shard 0>>> 1 birds
# >> Converting image 585/14486 shard 0>>> 1 birds
# >> Converting image 586/14486 shard 0>>> 0 flower
# >> Converting image 587/14486 shard 0>>> 1 birds
# >> Converting image 588/14486 shard 0>>> 1 birds
# >> Converting image 589/14486 shard 0>>> 1 birds
# >> Converting image 590/14486 shard 0>>> 1 birds
# >> Converting image 591/14486 shard 0>>> 3 faces
# >> Converting image 592/14486 shard 0>>> 1 birds
# >> Converting image 593/14486 shard 0>>> 0 flower
# >> Converting image 594/14486 shard 0>>> 0 flower
# >> Converting image 595/14486 shard 0>>> 0 flower
# >> Converting image 596/14486 shard 0>>> 1 birds
# >> Converting image 597/14486 shard 0>>> 0 flower
# >> Converting image 598/14486 shard 0>>> 1 birds
# >> Converting image 599/14486 shard 0>>> 1 birds
# >> Converting image 600/14486 shard 0>>> 0 flower
# >> Converting image 601/14486 shard 0>>> 1 birds
# >> Converting image 602/14486 shard 0>>> 0 flower
# >> Converting image 603/14486 shard 0>>> 1 birds
# >> Converting image 604/14486 shard 0>>> 0 flower
# >> Converting image 605/14486 shard 0>>> 1 birds
# >> Converting image 606/14486 shard 0>>> 1 birds
# >> Converting image 607/14486 shard 0>>> 0 flower
# >> Converting image 608/14486 shard 0>>> 0 flower
# >> Converting image 609/14486 shard 0>>> 3 faces
# >> Converting image 610/14486 shard 0>>> 0 flower
# >> Converting image 611/14486 shard 0>>> 0 flower
# >> Converting image 612/14486 shard 0>>> 0 flower
# >> Converting image 613/14486 shard 0>>> 1 birds
# >> Converting image 614/14486 shard 0>>> 3 faces
# >> Converting image 615/14486 shard 0>>> 0 flower
# >> Converting image 616/14486 shard 0>>> 1 birds
# >> Converting image 617/14486 shard 0>>> 1 birds
# >> Converting image 618/14486 shard 0>>> 1 birds
# >> Converting image 619/14486 shard 0>>> 1 birds
# >> Converting image 620/14486 shard 0>>> 0 flower
# >> Converting image 621/14486 shard 0>>> 1 birds
# >> Converting image 622/14486 shard 0>>> 0 flower
# >> Converting image 623/14486 shard 0>>> 1 birds
# >> Converting image 624/14486 shard 0>>> 2 horse
# >> Converting image 625/14486 shard 0>>> 1 birds
# >> Converting image 626/14486 shard 0>>> 0 flower
# >> Converting image 627/14486 shard 0>>> 0 flower
# >> Converting image 628/14486 shard 0>>> 1 birds
# >> Converting image 629/14486 shard 0>>> 1 birds
# >> Converting image 630/14486 shard 0>>> 1 birds
# >> Converting image 631/14486 shard 0>>> 0 flower
# >> Converting image 632/14486 shard 0>>> 1 birds
# >> Converting image 633/14486 shard 0>>> 1 birds
# >> Converting image 634/14486 shard 0>>> 1 birds
# >> Converting image 635/14486 shard 0>>> 0 flower
# >> Converting image 636/14486 shard 0>>> 1 birds
# >> Converting image 637/14486 shard 0>>> 1 birds
# >> Converting image 638/14486 shard 0>>> 0 flower
# >> Converting image 639/14486 shard 0>>> 1 birds
# >> Converting image 640/14486 shard 0>>> 3 faces
# >> Converting image 641/14486 shard 0>>> 1 birds
# >> Converting image 642/14486 shard 0>>> 0 flower
# >> Converting image 643/14486 shard 0>>> 1 birds
# >> Converting image 644/14486 shard 0>>> 1 birds
# >> Converting image 645/14486 shard 0>>> 1 birds
# >> Converting image 646/14486 shard 0>>> 0 flower
# >> Converting image 647/14486 shard 0>>> 0 flower
# >> Converting image 648/14486 shard 0>>> 1 birds
# >> Converting image 649/14486 shard 0>>> 0 flower
# >> Converting image 650/14486 shard 0>>> 1 birds
# >> Converting image 651/14486 shard 0>>> 0 flower
# >> Converting image 652/14486 shard 0>>> 1 birds
# >> Converting image 653/14486 shard 0>>> 0 flower
# >> Converting image 654/14486 shard 0>>> 1 birds
# >> Converting image 655/14486 shard 0>>> 0 flower
# >> Converting image 656/14486 shard 0>>> 0 flower
# >> Converting image 657/14486 shard 0>>> 1 birds
# >> Converting image 658/14486 shard 0>>> 0 flower
# >> Converting image 659/14486 shard 0>>> 0 flower
# >> Converting image 660/14486 shard 0>>> 1 birds
# >> Converting image 661/14486 shard 0>>> 0 flower
# >> Converting image 662/14486 shard 0>>> 0 flower
# >> Converting image 663/14486 shard 0>>> 1 birds
# >> Converting image 664/14486 shard 0>>> 1 birds
# >> Converting image 665/14486 shard 0>>> 1 birds
# >> Converting image 666/14486 shard 0>>> 1 birds
# >> Converting image 667/14486 shard 0>>> 1 birds
# >> Converting image 668/14486 shard 0>>> 1 birds
# >> Converting image 669/14486 shard 0>>> 2 horse
# >> Converting image 670/14486 shard 0>>> 1 birds
# >> Converting image 671/14486 shard 0>>> 1 birds
# >> Converting image 672/14486 shard 0>>> 1 birds
# >> Converting image 673/14486 shard 0>>> 1 birds
# >> Converting image 674/14486 shard 0>>> 0 flower
# >> Converting image 675/14486 shard 0>>> 0 flower
# >> Converting image 676/14486 shard 0>>> 0 flower
# >> Converting image 677/14486 shard 0>>> 0 flower
# >> Converting image 678/14486 shard 0>>> 0 flower
# >> Converting image 679/14486 shard 0>>> 0 flower
# >> Converting image 680/14486 shard 0>>> 1 birds
# >> Converting image 681/14486 shard 0>>> 1 birds
# >> Converting image 682/14486 shard 0>>> 0 flower
# >> Converting image 683/14486 shard 0>>> 0 flower
# >> Converting image 684/14486 shard 0>>> 1 birds
# >> Converting image 685/14486 shard 0>>> 0 flower
# >> Converting image 686/14486 shard 0>>> 0 flower
# >> Converting image 687/14486 shard 0>>> 0 flower
# >> Converting image 688/14486 shard 0>>> 0 flower
# >> Converting image 689/14486 shard 0>>> 0 flower
# >> Converting image 690/14486 shard 0>>> 0 flower
# >> Converting image 691/14486 shard 0>>> 3 faces
# >> Converting image 692/14486 shard 0>>> 1 birds
# >> Converting image 693/14486 shard 0>>> 0 flower
# >> Converting image 694/14486 shard 0>>> 0 flower
# >> Converting image 695/14486 shard 0>>> 0 flower
# >> Converting image 696/14486 shard 0>>> 0 flower
# >> Converting image 697/14486 shard 0>>> 0 flower
# >> Converting image 698/14486 shard 0>>> 1 birds
# >> Converting image 699/14486 shard 0>>> 0 flower
# >> Converting image 700/14486 shard 0>>> 2 horse
# >> Converting image 701/14486 shard 0>>> 1 birds
# >> Converting image 702/14486 shard 0>>> 2 horse
# >> Converting image 703/14486 shard 0>>> 1 birds
# >> Converting image 704/14486 shard 0>>> 0 flower
# >> Converting image 705/14486 shard 0>>> 1 birds
# >> Converting image 706/14486 shard 0>>> 0 flower
# >> Converting image 707/14486 shard 0>>> 1 birds
# >> Converting image 708/14486 shard 0>>> 1 birds
# >> Converting image 709/14486 shard 0>>> 1 birds
# >> Converting image 710/14486 shard 0>>> 0 flower
# >> Converting image 711/14486 shard 0>>> 0 flower
# >> Converting image 712/14486 shard 0>>> 0 flower
# >> Converting image 713/14486 shard 0>>> 0 flower
# >> Converting image 714/14486 shard 0>>> 1 birds
# >> Converting image 715/14486 shard 0>>> 0 flower
# >> Converting image 716/14486 shard 0>>> 1 birds
# >> Converting image 717/14486 shard 0>>> 0 flower
# >> Converting image 718/14486 shard 0>>> 1 birds
# >> Converting image 719/14486 shard 0>>> 0 flower
# >> Converting image 720/14486 shard 0>>> 2 horse
# >> Converting image 721/14486 shard 0>>> 0 flower
# >> Converting image 722/14486 shard 0>>> 1 birds
# >> Converting image 723/14486 shard 0>>> 0 flower
# >> Converting image 724/14486 shard 0>>> 1 birds
# >> Converting image 725/14486 shard 0>>> 0 flower
# >> Converting image 726/14486 shard 0>>> 0 flower
# >> Converting image 727/14486 shard 0>>> 1 birds
# >> Converting image 728/14486 shard 0>>> 0 flower
# >> Converting image 729/14486 shard 0>>> 0 flower
# >> Converting image 730/14486 shard 0>>> 0 flower
# >> Converting image 731/14486 shard 0>>> 1 birds
# >> Converting image 732/14486 shard 0>>> 1 birds
# >> Converting image 733/14486 shard 0>>> 0 flower
# >> Converting image 734/14486 shard 0>>> 1 birds
# >> Converting image 735/14486 shard 0>>> 1 birds
# >> Converting image 736/14486 shard 0>>> 1 birds
# >> Converting image 737/14486 shard 0>>> 0 flower
# >> Converting image 738/14486 shard 0>>> 0 flower
# >> Converting image 739/14486 shard 0>>> 0 flower
# >> Converting image 740/14486 shard 0>>> 0 flower
# >> Converting image 741/14486 shard 0>>> 0 flower
# >> Converting image 742/14486 shard 0>>> 0 flower
# >> Converting image 743/14486 shard 0>>> 1 birds
# >> Converting image 744/14486 shard 0>>> 0 flower
# >> Converting image 745/14486 shard 0>>> 1 birds
# >> Converting image 746/14486 shard 0>>> 1 birds
# >> Converting image 747/14486 shard 0>>> 1 birds
# >> Converting image 748/14486 shard 0>>> 1 birds
# >> Converting image 749/14486 shard 0>>> 1 birds
# >> Converting image 750/14486 shard 0>>> 1 birds
# >> Converting image 751/14486 shard 0>>> 1 birds
# >> Converting image 752/14486 shard 0>>> 0 flower
# >> Converting image 753/14486 shard 0>>> 0 flower
# >> Converting image 754/14486 shard 0>>> 1 birds
# >> Converting image 755/14486 shard 0>>> 1 birds
# >> Converting image 756/14486 shard 0>>> 0 flower
# >> Converting image 757/14486 shard 0>>> 0 flower
# >> Converting image 758/14486 shard 0>>> 0 flower
# >> Converting image 759/14486 shard 0>>> 0 flower
# >> Converting image 760/14486 shard 0>>> 0 flower
# >> Converting image 761/14486 shard 0>>> 1 birds
# >> Converting image 762/14486 shard 0>>> 0 flower
# >> Converting image 763/14486 shard 0>>> 0 flower
# >> Converting image 764/14486 shard 0>>> 0 flower
# >> Converting image 765/14486 shard 0>>> 1 birds
# >> Converting image 766/14486 shard 0>>> 1 birds
# >> Converting image 767/14486 shard 0>>> 0 flower
# >> Converting image 768/14486 shard 0>>> 1 birds
# >> Converting image 769/14486 shard 0>>> 1 birds
# >> Converting image 770/14486 shard 0>>> 1 birds
# >> Converting image 771/14486 shard 0>>> 0 flower
# >> Converting image 772/14486 shard 0>>> 0 flower
# >> Converting image 773/14486 shard 0>>> 1 birds
# >> Converting image 774/14486 shard 0>>> 1 birds
# >> Converting image 775/14486 shard 0>>> 0 flower
# >> Converting image 776/14486 shard 0>>> 2 horse
# >> Converting image 777/14486 shard 0>>> 2 horse
# >> Converting image 778/14486 shard 0>>> 0 flower
# >> Converting image 779/14486 shard 0>>> 1 birds
# >> Converting image 780/14486 shard 0>>> 1 birds
# >> Converting image 781/14486 shard 0>>> 1 birds
# >> Converting image 782/14486 shard 0>>> 1 birds
# >> Converting image 783/14486 shard 0>>> 0 flower
# >> Converting image 784/14486 shard 0>>> 1 birds
# >> Converting image 785/14486 shard 0>>> 0 flower
# >> Converting image 786/14486 shard 0>>> 0 flower
# >> Converting image 787/14486 shard 0>>> 1 birds
# >> Converting image 788/14486 shard 0>>> 0 flower
# >> Converting image 789/14486 shard 0>>> 0 flower
# >> Converting image 790/14486 shard 0>>> 0 flower
# >> Converting image 791/14486 shard 0>>> 1 birds
# >> Converting image 792/14486 shard 0>>> 0 flower
# >> Converting image 793/14486 shard 0>>> 0 flower
# >> Converting image 794/14486 shard 0>>> 3 faces
# >> Converting image 795/14486 shard 0>>> 1 birds
# >> Converting image 796/14486 shard 0>>> 1 birds
# >> Converting image 797/14486 shard 0>>> 0 flower
# >> Converting image 798/14486 shard 0>>> 0 flower
# >> Converting image 799/14486 shard 0>>> 0 flower
# >> Converting image 800/14486 shard 0>>> 0 flower
# >> Converting image 801/14486 shard 0>>> 0 flower
# >> Converting image 802/14486 shard 0>>> 0 flower
# >> Converting image 803/14486 shard 0>>> 1 birds
# >> Converting image 804/14486 shard 0>>> 0 flower
# >> Converting image 805/14486 shard 0>>> 1 birds
# >> Converting image 806/14486 shard 0>>> 1 birds
# >> Converting image 807/14486 shard 0>>> 1 birds
# >> Converting image 808/14486 shard 0>>> 1 birds
# >> Converting image 809/14486 shard 0>>> 0 flower
# >> Converting image 810/14486 shard 0>>> 0 flower
# >> Converting image 811/14486 shard 0>>> 0 flower
# >> Converting image 812/14486 shard 0>>> 1 birds
# >> Converting image 813/14486 shard 0>>> 0 flower
# >> Converting image 814/14486 shard 0>>> 0 flower
# >> Converting image 815/14486 shard 0>>> 0 flower
# >> Converting image 816/14486 shard 0>>> 0 flower
# >> Converting image 817/14486 shard 0>>> 1 birds
# >> Converting image 818/14486 shard 0>>> 1 birds
# >> Converting image 819/14486 shard 0>>> 1 birds
# >> Converting image 820/14486 shard 0>>> 0 flower
# >> Converting image 821/14486 shard 0>>> 1 birds
# >> Converting image 822/14486 shard 0>>> 1 birds
# >> Converting image 823/14486 shard 0>>> 1 birds
# >> Converting image 824/14486 shard 0>>> 0 flower
# >> Converting image 825/14486 shard 0>>> 1 birds
# >> Converting image 826/14486 shard 0>>> 1 birds
# >> Converting image 827/14486 shard 0>>> 0 flower
# >> Converting image 828/14486 shard 0>>> 1 birds
# >> Converting image 829/14486 shard 0>>> 0 flower
# >> Converting image 830/14486 shard 0>>> 1 birds
# >> Converting image 831/14486 shard 0>>> 0 flower
# >> Converting image 832/14486 shard 0>>> 0 flower
# >> Converting image 833/14486 shard 0>>> 1 birds
# >> Converting image 834/14486 shard 0>>> 1 birds
# >> Converting image 835/14486 shard 0>>> 1 birds
# >> Converting image 836/14486 shard 0>>> 2 horse
# >> Converting image 837/14486 shard 0>>> 2 horse
# >> Converting image 838/14486 shard 0>>> 1 birds
# >> Converting image 839/14486 shard 0>>> 0 flower
# >> Converting image 840/14486 shard 0>>> 0 flower
# >> Converting image 841/14486 shard 0>>> 0 flower
# >> Converting image 842/14486 shard 0>>> 1 birds
# >> Converting image 843/14486 shard 0>>> 1 birds
# >> Converting image 844/14486 shard 0>>> 1 birds
# >> Converting image 845/14486 shard 0>>> 2 horse
# >> Converting image 846/14486 shard 0>>> 0 flower
# >> Converting image 847/14486 shard 0>>> 1 birds
# >> Converting image 848/14486 shard 0>>> 0 flower
# >> Converting image 849/14486 shard 0>>> 0 flower
# >> Converting image 850/14486 shard 0>>> 0 flower
# >> Converting image 851/14486 shard 0>>> 0 flower
# >> Converting image 852/14486 shard 0>>> 0 flower
# >> Converting image 853/14486 shard 0>>> 0 flower
# >> Converting image 854/14486 shard 0>>> 1 birds
# >> Converting image 855/14486 shard 0>>> 1 birds
# >> Converting image 856/14486 shard 0>>> 0 flower
# >> Converting image 857/14486 shard 0>>> 1 birds
# >> Converting image 858/14486 shard 0>>> 0 flower
# >> Converting image 859/14486 shard 0>>> 3 faces
# >> Converting image 860/14486 shard 0>>> 0 flower
# >> Converting image 861/14486 shard 0>>> 0 flower
# >> Converting image 862/14486 shard 0>>> 0 flower
# >> Converting image 863/14486 shard 0>>> 3 faces
# >> Converting image 864/14486 shard 0>>> 1 birds
# >> Converting image 865/14486 shard 0>>> 0 flower
# >> Converting image 866/14486 shard 0>>> 0 flower
# >> Converting image 867/14486 shard 0>>> 1 birds
# >> Converting image 868/14486 shard 0>>> 1 birds
# >> Converting image 869/14486 shard 0>>> 1 birds
# >> Converting image 870/14486 shard 0>>> 0 flower
# >> Converting image 871/14486 shard 0>>> 1 birds
# >> Converting image 872/14486 shard 0>>> 1 birds
# >> Converting image 873/14486 shard 0>>> 1 birds
# >> Converting image 874/14486 shard 0>>> 0 flower
# >> Converting image 875/14486 shard 0>>> 1 birds
# >> Converting image 876/14486 shard 0>>> 1 birds
# >> Converting image 877/14486 shard 0>>> 3 faces
# >> Converting image 878/14486 shard 0>>> 0 flower
# >> Converting image 879/14486 shard 0>>> 1 birds
# >> Converting image 880/14486 shard 0>>> 1 birds
# >> Converting image 881/14486 shard 0>>> 0 flower
# >> Converting image 882/14486 shard 0>>> 0 flower
# >> Converting image 883/14486 shard 0>>> 1 birds
# >> Converting image 884/14486 shard 0>>> 0 flower
# >> Converting image 885/14486 shard 0>>> 0 flower
# >> Converting image 886/14486 shard 0>>> 1 birds
# >> Converting image 887/14486 shard 0>>> 0 flower
# >> Converting image 888/14486 shard 0>>> 1 birds
# >> Converting image 889/14486 shard 0>>> 0 flower
# >> Converting image 890/14486 shard 0>>> 1 birds
# >> Converting image 891/14486 shard 0>>> 0 flower
# >> Converting image 892/14486 shard 0>>> 0 flower
# >> Converting image 893/14486 shard 0>>> 0 flower
# >> Converting image 894/14486 shard 0>>> 0 flower
# >> Converting image 895/14486 shard 0>>> 0 flower
# >> Converting image 896/14486 shard 0>>> 3 faces
# >> Converting image 897/14486 shard 0>>> 1 birds
# >> Converting image 898/14486 shard 0>>> 0 flower
# >> Converting image 899/14486 shard 0>>> 0 flower
# >> Converting image 900/14486 shard 0>>> 0 flower
# >> Converting image 901/14486 shard 0>>> 1 birds
# >> Converting image 902/14486 shard 0>>> 0 flower
# >> Converting image 903/14486 shard 0>>> 0 flower
# >> Converting image 904/14486 shard 0>>> 1 birds
# >> Converting image 905/14486 shard 0>>> 0 flower
# >> Converting image 906/14486 shard 0>>> 2 horse
# >> Converting image 907/14486 shard 0>>> 0 flower
# >> Converting image 908/14486 shard 0>>> 1 birds
# >> Converting image 909/14486 shard 0>>> 1 birds
# >> Converting image 910/14486 shard 0>>> 0 flower
# >> Converting image 911/14486 shard 0>>> 0 flower
# >> Converting image 912/14486 shard 0>>> 0 flower
# >> Converting image 913/14486 shard 0>>> 1 birds
# >> Converting image 914/14486 shard 0>>> 1 birds
# >> Converting image 915/14486 shard 0>>> 1 birds
# >> Converting image 916/14486 shard 0>>> 0 flower
# >> Converting image 917/14486 shard 0>>> 1 birds
# >> Converting image 918/14486 shard 0>>> 0 flower
# >> Converting image 919/14486 shard 0>>> 0 flower
# >> Converting image 920/14486 shard 0>>> 0 flower
# >> Converting image 921/14486 shard 0>>> 1 birds
# >> Converting image 922/14486 shard 0>>> 1 birds
# >> Converting image 923/14486 shard 0>>> 0 flower
# >> Converting image 924/14486 shard 0>>> 0 flower
# >> Converting image 925/14486 shard 0>>> 0 flower
# >> Converting image 926/14486 shard 0>>> 0 flower
# >> Converting image 927/14486 shard 0>>> 1 birds
# >> Converting image 928/14486 shard 0>>> 0 flower
# >> Converting image 929/14486 shard 0>>> 0 flower
# >> Converting image 930/14486 shard 0>>> 0 flower
# >> Converting image 931/14486 shard 0>>> 0 flower
# >> Converting image 932/14486 shard 0>>> 0 flower
# >> Converting image 933/14486 shard 0>>> 2 horse
# >> Converting image 934/14486 shard 0>>> 0 flower
# >> Converting image 935/14486 shard 0>>> 1 birds
# >> Converting image 936/14486 shard 0>>> 0 flower
# >> Converting image 937/14486 shard 0>>> 0 flower
# >> Converting image 938/14486 shard 0>>> 0 flower
# >> Converting image 939/14486 shard 0>>> 0 flower
# >> Converting image 940/14486 shard 0>>> 1 birds
# >> Converting image 941/14486 shard 0>>> 0 flower
# >> Converting image 942/14486 shard 0>>> 0 flower
# >> Converting image 943/14486 shard 0>>> 0 flower
# >> Converting image 944/14486 shard 0>>> 3 faces
# >> Converting image 945/14486 shard 0>>> 1 birds
# >> Converting image 946/14486 shard 0>>> 0 flower
# >> Converting image 947/14486 shard 0>>> 0 flower
# >> Converting image 948/14486 shard 0>>> 0 flower
# >> Converting image 949/14486 shard 0>>> 1 birds
# >> Converting image 950/14486 shard 0>>> 0 flower
# >> Converting image 951/14486 shard 0>>> 0 flower
# >> Converting image 952/14486 shard 0>>> 1 birds
# >> Converting image 953/14486 shard 0>>> 0 flower
# >> Converting image 954/14486 shard 0>>> 0 flower
# >> Converting image 955/14486 shard 0>>> 1 birds
# >> Converting image 956/14486 shard 0>>> 1 birds
# >> Converting image 957/14486 shard 0>>> 2 horse
# >> Converting image 958/14486 shard 0>>> 1 birds
# >> Converting image 959/14486 shard 0>>> 1 birds
# >> Converting image 960/14486 shard 0>>> 0 flower
# >> Converting image 961/14486 shard 0>>> 1 birds
# >> Converting image 962/14486 shard 0>>> 0 flower
# >> Converting image 963/14486 shard 0>>> 1 birds
# >> Converting image 964/14486 shard 0>>> 0 flower
# >> Converting image 965/14486 shard 0>>> 0 flower
# >> Converting image 966/14486 shard 0>>> 0 flower
# >> Converting image 967/14486 shard 0>>> 0 flower
# >> Converting image 968/14486 shard 0>>> 0 flower
# ...
# >> Converting image 207/500 shard 1>>> 0 flower
# >> Converting image 208/500 shard 1>>> 2 horse
# >> Converting image 209/500 shard 1>>> 1 birds
# >> Converting image 210/500 shard 1>>> 1 birds
# >> Converting image 211/500 shard 1>>> 0 flower
# >> Converting image 212/500 shard 1>>> 1 birds
# >> Converting image 213/500 shard 1>>> 1 birds
# >> Converting image 214/500 shard 1>>> 0 flower
# >> Converting image 215/500 shard 1>>> 1 birds
# >> Converting image 216/500 shard 1>>> 0 flower
# >> Converting image 217/500 shard 1>>> 1 birds
# >> Converting image 218/500 shard 1>>> 1 birds
# >> Converting image 219/500 shard 1>>> 2 horse
# >> Converting image 220/500 shard 1>>> 0 flower
# >> Converting image 221/500 shard 1>>> 0 flower
# >> Converting image 222/500 shard 1>>> 0 flower
# >> Converting image 223/500 shard 1>>> 0 flower
# >> Converting image 224/500 shard 1>>> 0 flower
# >> Converting image 225/500 shard 1>>> 0 flower
# >> Converting image 226/500 shard 1>>> 1 birds
# >> Converting image 227/500 shard 1>>> 0 flower
# >> Converting image 228/500 shard 1>>> 0 flower
# >> Converting image 229/500 shard 1>>> 1 birds
# >> Converting image 230/500 shard 1>>> 0 flower
# >> Converting image 231/500 shard 1>>> 2 horse
# >> Converting image 232/500 shard 1>>> 1 birds
# >> Converting image 233/500 shard 1>>> 1 birds
# >> Converting image 234/500 shard 1>>> 2 horse
# >> Converting image 235/500 shard 1>>> 2 horse
# >> Converting image 236/500 shard 1>>> 0 flower
# >> Converting image 237/500 shard 1>>> 0 flower
# >> Converting image 238/500 shard 1>>> 0 flower
# >> Converting image 239/500 shard 1>>> 0 flower
# >> Converting image 240/500 shard 1>>> 0 flower
# >> Converting image 241/500 shard 1>>> 0 flower
# >> Converting image 242/500 shard 1>>> 0 flower
# >> Converting image 243/500 shard 1>>> 1 birds
# >> Converting image 244/500 shard 1>>> 0 flower
# >> Converting image 245/500 shard 1>>> 0 flower
# >> Converting image 246/500 shard 1>>> 1 birds
# >> Converting image 247/500 shard 1>>> 1 birds
# >> Converting image 248/500 shard 1>>> 1 birds
# >> Converting image 249/500 shard 1>>> 1 birds
# >> Converting image 250/500 shard 1>>> 1 birds
# >> Converting image 251/500 shard 2>>> 0 flower
# >> Converting image 252/500 shard 2>>> 1 birds
# >> Converting image 253/500 shard 2>>> 1 birds
# >> Converting image 254/500 shard 2>>> 0 flower
# >> Converting image 255/500 shard 2>>> 1 birds
# >> Converting image 256/500 shard 2>>> 0 flower
# >> Converting image 257/500 shard 2>>> 1 birds
# >> Converting image 258/500 shard 2>>> 0 flower
# >> Converting image 259/500 shard 2>>> 0 flower
# >> Converting image 260/500 shard 2>>> 0 flower
# >> Converting image 261/500 shard 2>>> 1 birds
# >> Converting image 262/500 shard 2>>> 0 flower
# >> Converting image 263/500 shard 2>>> 0 flower
# >> Converting image 264/500 shard 2>>> 0 flower
# >> Converting image 265/500 shard 2>>> 1 birds
# >> Converting image 266/500 shard 2>>> 1 birds
# >> Converting image 267/500 shard 2>>> 0 flower
# >> Converting image 268/500 shard 2>>> 0 flower
# >> Converting image 269/500 shard 2>>> 0 flower
# >> Converting image 270/500 shard 2>>> 0 flower
# >> Converting image 271/500 shard 2>>> 1 birds
# >> Converting image 272/500 shard 2>>> 1 birds
# >> Converting image 273/500 shard 2>>> 1 birds
# >> Converting image 274/500 shard 2>>> 0 flower
# >> Converting image 275/500 shard 2>>> 1 birds
# >> Converting image 276/500 shard 2>>> 1 birds
# >> Converting image 277/500 shard 2>>> 0 flower
# >> Converting image 278/500 shard 2>>> 0 flower
# >> Converting image 279/500 shard 2>>> 1 birds
# >> Converting image 280/500 shard 2>>> 1 birds
# >> Converting image 281/500 shard 2>>> 1 birds
# >> Converting image 282/500 shard 2>>> 2 horse
# >> Converting image 283/500 shard 2>>> 0 flower
# >> Converting image 284/500 shard 2>>> 0 flower
# >> Converting image 285/500 shard 2>>> 0 flower
# >> Converting image 286/500 shard 2>>> 1 birds
# >> Converting image 287/500 shard 2>>> 0 flower
# >> Converting image 288/500 shard 2>>> 1 birds
# >> Converting image 289/500 shard 2>>> 0 flower
# >> Converting image 290/500 shard 2>>> 0 flower
# >> Converting image 291/500 shard 2>>> 1 birds
# >> Converting image 292/500 shard 2>>> 0 flower
# >> Converting image 293/500 shard 2>>> 0 flower
# >> Converting image 294/500 shard 2>>> 1 birds
# >> Converting image 295/500 shard 2>>> 1 birds
# >> Converting image 296/500 shard 2>>> 1 birds
# >> Converting image 297/500 shard 2>>> 1 birds
# >> Converting image 298/500 shard 2>>> 1 birds
# >> Converting image 299/500 shard 2>>> 0 flower
# >> Converting image 300/500 shard 2>>> 1 birds
# >> Converting image 301/500 shard 2>>> 0 flower
# >> Converting image 302/500 shard 2>>> 0 flower
# >> Converting image 303/500 shard 2>>> 0 flower
# >> Converting image 304/500 shard 2>>> 0 flower
# >> Converting image 305/500 shard 2>>> 0 flower
# >> Converting image 306/500 shard 2>>> 1 birds
# >> Converting image 307/500 shard 2>>> 0 flower
# >> Converting image 308/500 shard 2>>> 1 birds
# >> Converting image 309/500 shard 2>>> 1 birds
# >> Converting image 310/500 shard 2>>> 1 birds
# >> Converting image 311/500 shard 2>>> 0 flower
# >> Converting image 312/500 shard 2>>> 0 flower
# >> Converting image 313/500 shard 2>>> 1 birds
# >> Converting image 314/500 shard 2>>> 1 birds
# >> Converting image 315/500 shard 2>>> 0 flower
# >> Converting image 316/500 shard 2>>> 0 flower
# >> Converting image 317/500 shard 2>>> 0 flower
# >> Converting image 318/500 shard 2>>> 0 flower
# >> Converting image 319/500 shard 2>>> 0 flower
# >> Converting image 320/500 shard 2>>> 0 flower
# >> Converting image 321/500 shard 2>>> 0 flower
# >> Converting image 322/500 shard 2>>> 0 flower
# >> Converting image 323/500 shard 2>>> 1 birds
# >> Converting image 324/500 shard 2>>> 0 flower
# >> Converting image 325/500 shard 2>>> 0 flower
# >> Converting image 326/500 shard 2>>> 1 birds
# >> Converting image 327/500 shard 2>>> 1 birds
# >> Converting image 328/500 shard 2>>> 3 faces
# >> Converting image 329/500 shard 2>>> 2 horse
# >> Converting image 330/500 shard 2>>> 0 flower
# >> Converting image 331/500 shard 2>>> 0 flower
# >> Converting image 332/500 shard 2>>> 2 horse
# >> Converting image 333/500 shard 2>>> 0 flower
# >> Converting image 334/500 shard 2>>> 0 flower
# >> Converting image 335/500 shard 2>>> 0 flower
# >> Converting image 336/500 shard 2>>> 1 birds
# >> Converting image 337/500 shard 2>>> 1 birds
# >> Converting image 338/500 shard 2>>> 0 flower
# >> Converting image 339/500 shard 2>>> 1 birds
# >> Converting image 340/500 shard 2>>> 0 flower
# >> Converting image 341/500 shard 2>>> 0 flower
# >> Converting image 342/500 shard 2>>> 0 flower
# >> Converting image 343/500 shard 2>>> 0 flower
# >> Converting image 344/500 shard 2>>> 1 birds
# >> Converting image 345/500 shard 2>>> 0 flower
# >> Converting image 346/500 shard 2>>> 0 flower
# >> Converting image 347/500 shard 2>>> 1 birds
# >> Converting image 348/500 shard 2>>> 0 flower
# >> Converting image 349/500 shard 2>>> 1 birds
# >> Converting image 350/500 shard 2>>> 1 birds
# >> Converting image 351/500 shard 2>>> 0 flower
# >> Converting image 352/500 shard 2>>> 0 flower
# >> Converting image 353/500 shard 2>>> 1 birds
# >> Converting image 354/500 shard 2>>> 1 birds
# >> Converting image 355/500 shard 2>>> 0 flower
# >> Converting image 356/500 shard 2>>> 0 flower
# >> Converting image 357/500 shard 2>>> 1 birds
# >> Converting image 358/500 shard 2>>> 0 flower
# >> Converting image 359/500 shard 2>>> 0 flower
# >> Converting image 360/500 shard 2>>> 0 flower
# >> Converting image 361/500 shard 2>>> 1 birds
# >> Converting image 362/500 shard 2>>> 0 flower
# >> Converting image 363/500 shard 2>>> 0 flower
# >> Converting image 364/500 shard 2>>> 0 flower
# >> Converting image 365/500 shard 2>>> 0 flower
# >> Converting image 366/500 shard 2>>> 1 birds
# >> Converting image 367/500 shard 2>>> 0 flower
# >> Converting image 368/500 shard 2>>> 0 flower
# >> Converting image 369/500 shard 2>>> 1 birds
# >> Converting image 370/500 shard 2>>> 2 horse
# >> Converting image 371/500 shard 2>>> 1 birds
# >> Converting image 372/500 shard 2>>> 0 flower
# >> Converting image 373/500 shard 2>>> 0 flower
# >> Converting image 374/500 shard 2>>> 1 birds
# >> Converting image 375/500 shard 2>>> 1 birds
# >> Converting image 376/500 shard 3>>> 0 flower
# >> Converting image 377/500 shard 3>>> 0 flower
# >> Converting image 378/500 shard 3>>> 1 birds
# >> Converting image 379/500 shard 3>>> 1 birds
# >> Converting image 380/500 shard 3>>> 1 birds
# >> Converting image 381/500 shard 3>>> 0 flower
# >> Converting image 382/500 shard 3>>> 0 flower
# >> Converting image 383/500 shard 3>>> 1 birds
# >> Converting image 384/500 shard 3>>> 0 flower
# >> Converting image 385/500 shard 3>>> 0 flower
# >> Converting image 386/500 shard 3>>> 1 birds
# >> Converting image 387/500 shard 3>>> 1 birds
# >> Converting image 388/500 shard 3>>> 0 flower
# >> Converting image 389/500 shard 3>>> 1 birds
# >> Converting image 390/500 shard 3>>> 1 birds
# >> Converting image 391/500 shard 3>>> 1 birds
# >> Converting image 392/500 shard 3>>> 1 birds
# >> Converting image 393/500 shard 3>>> 0 flower
# >> Converting image 394/500 shard 3>>> 1 birds
# >> Converting image 395/500 shard 3>>> 1 birds
# >> Converting image 396/500 shard 3>>> 0 flower
# >> Converting image 397/500 shard 3>>> 0 flower
# >> Converting image 398/500 shard 3>>> 1 birds
# >> Converting image 399/500 shard 3>>> 0 flower
# >> Converting image 400/500 shard 3>>> 1 birds
# >> Converting image 401/500 shard 3>>> 1 birds
# >> Converting image 402/500 shard 3>>> 0 flower
# >> Converting image 403/500 shard 3>>> 0 flower
# >> Converting image 404/500 shard 3>>> 1 birds
# >> Converting image 405/500 shard 3>>> 0 flower
# >> Converting image 406/500 shard 3>>> 1 birds
# >> Converting image 407/500 shard 3>>> 0 flower
# >> Converting image 408/500 shard 3>>> 0 flower
# >> Converting image 409/500 shard 3>>> 1 birds
# >> Converting image 410/500 shard 3>>> 0 flower
# >> Converting image 411/500 shard 3>>> 0 flower
# >> Converting image 412/500 shard 3>>> 0 flower
# >> Converting image 413/500 shard 3>>> 0 flower
# >> Converting image 414/500 shard 3>>> 0 flower
# >> Converting image 415/500 shard 3>>> 0 flower
# >> Converting image 416/500 shard 3>>> 1 birds
# >> Converting image 417/500 shard 3>>> 1 birds
# >> Converting image 418/500 shard 3>>> 0 flower
# >> Converting image 419/500 shard 3>>> 1 birds
# >> Converting image 420/500 shard 3>>> 0 flower
# >> Converting image 421/500 shard 3>>> 0 flower
# >> Converting image 422/500 shard 3>>> 1 birds
# >> Converting image 423/500 shard 3>>> 0 flower
# >> Converting image 424/500 shard 3>>> 0 flower
# >> Converting image 425/500 shard 3>>> 0 flower
# >> Converting image 426/500 shard 3>>> 0 flower
# >> Converting image 427/500 shard 3>>> 0 flower
# >> Converting image 428/500 shard 3>>> 0 flower
# >> Converting image 429/500 shard 3>>> 1 birds
# >> Converting image 430/500 shard 3>>> 0 flower
# >> Converting image 431/500 shard 3>>> 0 flower
# >> Converting image 432/500 shard 3>>> 1 birds
# >> Converting image 433/500 shard 3>>> 0 flower
# >> Converting image 434/500 shard 3>>> 1 birds
# >> Converting image 435/500 shard 3>>> 1 birds
# >> Converting image 436/500 shard 3>>> 1 birds
# >> Converting image 437/500 shard 3>>> 0 flower
# >> Converting image 438/500 shard 3>>> 1 birds
# >> Converting image 439/500 shard 3>>> 0 flower
# >> Converting image 440/500 shard 3>>> 1 birds
# >> Converting image 441/500 shard 3>>> 1 birds
# >> Converting image 442/500 shard 3>>> 1 birds
# >> Converting image 443/500 shard 3>>> 0 flower
# >> Converting image 444/500 shard 3>>> 3 faces
# >> Converting image 445/500 shard 3>>> 1 birds
# >> Converting image 446/500 shard 3>>> 0 flower
# >> Converting image 447/500 shard 3>>> 1 birds
# >> Converting image 448/500 shard 3>>> 0 flower
# >> Converting image 449/500 shard 3>>> 1 birds
# >> Converting image 450/500 shard 3>>> 0 flower
# >> Converting image 451/500 shard 3>>> 0 flower
# >> Converting image 452/500 shard 3>>> 2 horse
# >> Converting image 453/500 shard 3>>> 1 birds
# >> Converting image 454/500 shard 3>>> 0 flower
# >> Converting image 455/500 shard 3>>> 0 flower
# >> Converting image 456/500 shard 3>>> 1 birds
# >> Converting image 457/500 shard 3>>> 0 flower
# >> Converting image 458/500 shard 3>>> 0 flower
# >> Converting image 459/500 shard 3>>> 1 birds
# >> Converting image 460/500 shard 3>>> 1 birds
# >> Converting image 461/500 shard 3>>> 0 flower
# >> Converting image 462/500 shard 3>>> 0 flower
# >> Converting image 463/500 shard 3>>> 0 flower
# >> Converting image 464/500 shard 3>>> 0 flower
# >> Converting image 465/500 shard 3>>> 3 faces
# >> Converting image 466/500 shard 3>>> 1 birds
# >> Converting image 467/500 shard 3>>> 1 birds
# >> Converting image 468/500 shard 3>>> 1 birds
# >> Converting image 469/500 shard 3>>> 1 birds
# >> Converting image 470/500 shard 3>>> 0 flower
# >> Converting image 471/500 shard 3>>> 0 flower
# >> Converting image 472/500 shard 3>>> 0 flower
# >> Converting image 473/500 shard 3>>> 0 flower
# >> Converting image 474/500 shard 3>>> 0 flower
# >> Converting image 475/500 shard 3>>> 0 flower
# >> Converting image 476/500 shard 3>>> 0 flower
# >> Converting image 477/500 shard 3>>> 0 flower
# >> Converting image 478/500 shard 3>>> 1 birds
# >> Converting image 479/500 shard 3>>> 1 birds
# >> Converting image 480/500 shard 3>>> 1 birds
# >> Converting image 481/500 shard 3>>> 1 birds
# >> Converting image 482/500 shard 3>>> 0 flower
# >> Converting image 483/500 shard 3>>> 1 birds
# >> Converting image 484/500 shard 3>>> 0 flower
# >> Converting image 485/500 shard 3>>> 0 flower
# >> Converting image 486/500 shard 3>>> 0 flower
# >> Converting image 487/500 shard 3>>> 1 birds
# >> Converting image 488/500 shard 3>>> 0 flower
# >> Converting image 489/500 shard 3>>> 1 birds
# >> Converting image 490/500 shard 3>>> 0 flower
# >> Converting image 491/500 shard 3>>> 0 flower
# >> Converting image 492/500 shard 3>>> 2 horse
# >> Converting image 493/500 shard 3>>> 0 flower
# >> Converting image 494/500 shard 3>>> 1 birds
# >> Converting image 495/500 shard 3>>> 0 flower
# >> Converting image 496/500 shard 3>>> 1 birds
# >> Converting image 497/500 shard 3>>> 1 birds
# >> Converting image 498/500 shard 3>>> 0 flower
# >> Converting image 499/500 shard 3>>> 3 faces
# >> Converting image 500/500 shard 3>>> 1 birds
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# <ipython-input-11-309626aab1b8> in <module>()
#      24         # 输出labels文件
#      25         labels_to_class_names = dict(zip(range(len(class_names)), class_names))
# ---> 26         write_label_file(labels_to_class_names, LABELS_FILENAME)
#
# <ipython-input-9-0c42361a8830> in write_label_file(labels_to_class_names, dataset_dir, filename)
#       4         for label in labels_to_class_names:
#       5             class_name = labels_to_class_names[label]
# ----> 6             f.write('%d : %s \n'% (label, class_name))
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/lib/io/file_io.py in write(self, file_content)
#     106   def write(self, file_content):
#     107     """Writes file_content to the file. Appends to the end of the file."""
# --> 108     self._prewrite_check()
#     109     with errors.raise_exception_on_not_ok_status() as status:
#     110       pywrap_tensorflow.AppendToFile(
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/lib/io/file_io.py in _prewrite_check(self)
#      92       with errors.raise_exception_on_not_ok_status() as status:
#      93         self._writable_file = pywrap_tensorflow.CreateWritableFile(
# ---> 94             compat.as_bytes(self.__name), compat.as_bytes(self.__mode), status)
#      95
#      96   def _prepare_value(self, val):
#
# ~/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     524             None, None,
#     525             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 526             c_api.TF_GetCode(self.status.status))
#     527     # Delete the underlying status object from memory otherwise it stays alive
#     528     # as there is a reference to status from this from the traceback due to
#
# NotFoundError: slim/images/labels.txt/slim/images/labels.txt; No such file or directory
