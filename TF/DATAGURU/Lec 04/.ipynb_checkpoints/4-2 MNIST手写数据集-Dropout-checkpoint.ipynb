# %% [markdown]
# 先定义一个比较复杂的神经网络，主要是为了查看Dropout的效果。

# %% [markdown]
# 版本一：用全部神经元去训练，keep_prob设置为1.0。

# %%
import os
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# 载入数据集
mnist = input_data.read_data_sets(os.path.join(os.getcwd(), 'MNIST_data'), one_hot=True)

# 定义每个批次的大小
batch_size = 100
# 计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size  # 55000//100=550

# 定义两个placeholder
x = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, 10])

# 定义drop的保留neuron的比例 占位符
keep_prob = tf.placeholder(tf.float32)

# 创建一个简单的神经网络
# 一般权值的初始化会使用tf.truncated_norm()
W1 = tf.Variable(tf.truncated_normal([784, 2000], stddev=0.1))
# bias的初始化是0.1
b1 = tf.Variable(tf.zeros([2000]) + 0.1)
L1 = tf.nn.tanh(tf.matmul(x,W1)+b1)
L1_drop = tf.nn.dropout(L1, keep_prob)

W2 = tf.Variable(tf.truncated_normal([2000, 2000], stddev=0.1))
b2 = tf.Variable(tf.zeros([2000]) + 0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop,W2)+b2)
L2_drop = tf.nn.dropout(L2, keep_prob)

W3 = tf.Variable(tf.truncated_normal([2000, 1000], stddev=0.1))
b3 = tf.Variable(tf.zeros([1000]) + 0.1)
L3 = tf.nn.tanh(tf.matmul(L2_drop,W3)+b3)
L3_drop = tf.nn.dropout(L3, keep_prob)

W4 = tf.Variable(tf.truncated_normal([1000, 10], stddev=0.1))
b4 = tf.Variable(tf.zeros([10]) + 0.1)
prediction = tf.nn.softmax(tf.matmul(L3_drop,W4)+b4)


# 二次代价函数
# loss = tf.reduce_mean(tf.square(prediction - y))
# 使用交叉熵代价函数
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=prediction))

# 使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

# 初始化变量
init = tf.global_variables_initializer()

# 结果存放在一个布尔型的列表中
# 正确与否的True or False的列表
# tf.argmax返回一维张量中最大的值所在的索引位置
correct_prediction = tf.equal(tf.argmax(y, 1), tf.argmax(prediction, 1))

# 求准确率
# 通过tf.cast(x, dtype)将布尔型转换为浮点型
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

with tf.Session() as sess:
    sess.run(init)
    
    for epoch in range(21):
        for batch in range(n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 1.0})
        
        test_acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels, keep_prob: 1.0})
        train_acc = sess.run(accuracy,feed_dict={x:mnist.train.images,y:mnist.train.labels, keep_prob: 1.0})
        print("Iter " + str(epoch) + ",Testing Accuracy " + str(test_acc) +',Training Accuracy' + str(train_acc))
# Out:
# Extracting /Users/zoe/Documents/GitHub/July-NLP/TF/DATAGURU/Lec 03/MNIST_data/train-images-idx3-ubyte.gz
# Extracting /Users/zoe/Documents/GitHub/July-NLP/TF/DATAGURU/Lec 03/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting /Users/zoe/Documents/GitHub/July-NLP/TF/DATAGURU/Lec 03/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting /Users/zoe/Documents/GitHub/July-NLP/TF/DATAGURU/Lec 03/MNIST_data/t10k-labels-idx1-ubyte.gz
# Iter 0,Testing Accuracy 0.9495,Training Accuracy0.9586
# Iter 1,Testing Accuracy 0.9599,Training Accuracy0.9745455
# Iter 2,Testing Accuracy 0.964,Training Accuracy0.9828909
# Iter 3,Testing Accuracy 0.963,Training Accuracy0.9863091
# Iter 4,Testing Accuracy 0.9644,Training Accuracy0.9887818
# Iter 5,Testing Accuracy 0.9688,Training Accuracy0.99014544
# Iter 6,Testing Accuracy 0.9693,Training Accuracy0.9914182
# Iter 7,Testing Accuracy 0.9697,Training Accuracy0.9923273
# Iter 8,Testing Accuracy 0.9701,Training Accuracy0.9928
# Iter 9,Testing Accuracy 0.9702,Training Accuracy0.9932
# Iter 10,Testing Accuracy 0.9713,Training Accuracy0.9935273
# Iter 11,Testing Accuracy 0.9712,Training Accuracy0.9938727
# Iter 12,Testing Accuracy 0.9713,Training Accuracy0.99407274
# Iter 13,Testing Accuracy 0.9717,Training Accuracy0.9942545
# Iter 14,Testing Accuracy 0.9716,Training Accuracy0.99438184
# Iter 15,Testing Accuracy 0.9724,Training Accuracy0.9945818
# Iter 16,Testing Accuracy 0.9716,Training Accuracy0.9948364
# Iter 17,Testing Accuracy 0.9725,Training Accuracy0.995
# Iter 18,Testing Accuracy 0.9726,Training Accuracy0.9950909
# Iter 19,Testing Accuracy 0.9729,Training Accuracy0.9951818
# Iter 20,Testing Accuracy 0.9729,Training Accuracy0.99536365

# %% [markdown]
# keep_prob=1.0时，表明dropout，保留所有的神经元进行计算。

# %% [markdown]
# 一般权值的初始化会使用tf.truncated_normal()
#
# #### 创建一个简单的神经网络
# #### 一般权值的初始化会使用tf.truncated_normal()
# W1 = tf.Variable(tf.truncated_normal([784, 2000], stddev=0.1))
#
# #### bias的初始化是0.1
# b1 = tf.Variable(tf.zeros([2000]) + 0.1)
# L1 = tf.nn.tanh(tf.matmul(x,W1)+b1)
# L1_drop = tf.nn.dropout(L1, keep_prob)

# %% [markdown]
# 下面将keep_prob改为0.7

# %%
import os
import tensorflow as tf
from tensorflow.examples.tutorials.mnist import input_data

# 载入数据集
mnist = input_data.read_data_sets(os.path.join(os.getcwd(), 'MNIST_data'), one_hot=True)

# 定义每个批次的大小
batch_size = 100
# 计算一共有多少个批次
n_batch = mnist.train.num_examples // batch_size  # 55000//100=550

# 定义两个placeholder
x = tf.placeholder(tf.float32, [None, 784])
y = tf.placeholder(tf.float32, [None, 10])

# 定义drop的保留neuron的比例 占位符
keep_prob = tf.placeholder(tf.float32)

# 创建一个简单的神经网络
# 一般权值的初始化会使用tf.truncated_norm()
W1 = tf.Variable(tf.truncated_normal([784, 2000], stddev=0.1))
# bias的初始化是0.1
b1 = tf.Variable(tf.zeros([2000]) + 0.1)
L1 = tf.nn.tanh(tf.matmul(x,W1)+b1)
L1_drop = tf.nn.dropout(L1, keep_prob)

W2 = tf.Variable(tf.truncated_normal([2000, 2000], stddev=0.1))
b2 = tf.Variable(tf.zeros([2000]) + 0.1)
L2 = tf.nn.tanh(tf.matmul(L1_drop,W2)+b2)
L2_drop = tf.nn.dropout(L2, keep_prob)

W3 = tf.Variable(tf.truncated_normal([2000, 1000], stddev=0.1))
b3 = tf.Variable(tf.zeros([1000]) + 0.1)
L3 = tf.nn.tanh(tf.matmul(L2_drop,W3)+b3)
L3_drop = tf.nn.dropout(L3, keep_prob)

W4 = tf.Variable(tf.truncated_normal([1000, 10], stddev=0.1))
b4 = tf.Variable(tf.zeros([10]) + 0.1)
prediction = tf.nn.softmax(tf.matmul(L3_drop,W4)+b4)


# 二次代价函数
# loss = tf.reduce_mean(tf.square(prediction - y))
# 使用交叉熵代价函数
loss = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(labels=y, logits=prediction))

# 使用梯度下降法
train_step = tf.train.GradientDescentOptimizer(0.2).minimize(loss)

# 初始化变量
init = tf.global_variables_initializer()

# 结果存放在一个布尔型的列表中
# 正确与否的True or False的列表
# tf.argmax返回一维张量中最大的值所在的索引位置
correct_prediction = tf.equal(tf.argmax(y, 1), tf.argmax(prediction, 1))

# 求准确率
# 通过tf.cast(x, dtype)将布尔型转换为浮点型
accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))

with tf.Session() as sess:
    sess.run(init)
    
    for epoch in range(21):
        for batch in range(n_batch):
            batch_xs, batch_ys = mnist.train.next_batch(batch_size)
            sess.run(train_step, feed_dict={x: batch_xs, y: batch_ys, keep_prob: 0.7})
        
        test_acc = sess.run(accuracy,feed_dict={x:mnist.test.images,y:mnist.test.labels, keep_prob: 1.0})
        train_acc = sess.run(accuracy,feed_dict={x:mnist.train.images,y:mnist.train.labels, keep_prob: 1.0})
        print("Iter " + str(epoch) + ",Testing Accuracy " + str(test_acc) +',Training Accuracy' + str(train_acc))
# Out:
# Extracting /Users/zoe/Documents/GitHub/July-NLP/TF/DATAGURU/Lec 03/MNIST_data/train-images-idx3-ubyte.gz
# Extracting /Users/zoe/Documents/GitHub/July-NLP/TF/DATAGURU/Lec 03/MNIST_data/train-labels-idx1-ubyte.gz
# Extracting /Users/zoe/Documents/GitHub/July-NLP/TF/DATAGURU/Lec 03/MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting /Users/zoe/Documents/GitHub/July-NLP/TF/DATAGURU/Lec 03/MNIST_data/t10k-labels-idx1-ubyte.gz
# Iter 0,Testing Accuracy 0.9189,Training Accuracy0.91196364
# Iter 1,Testing Accuracy 0.9308,Training Accuracy0.9269091
# Iter 2,Testing Accuracy 0.937,Training Accuracy0.93523633
# Iter 3,Testing Accuracy 0.9401,Training Accuracy0.93947273
# Iter 4,Testing Accuracy 0.9451,Training Accuracy0.94665456
# Iter 5,Testing Accuracy 0.9486,Training Accuracy0.9486727
# Iter 6,Testing Accuracy 0.9484,Training Accuracy0.9518727
# Iter 7,Testing Accuracy 0.9508,Training Accuracy0.95347273
# Iter 8,Testing Accuracy 0.953,Training Accuracy0.95738184
# Iter 9,Testing Accuracy 0.9548,Training Accuracy0.9590182
# Iter 10,Testing Accuracy 0.9558,Training Accuracy0.96058184
# Iter 11,Testing Accuracy 0.9574,Training Accuracy0.9608909
# Iter 12,Testing Accuracy 0.9598,Training Accuracy0.9633273
# Iter 13,Testing Accuracy 0.9589,Training Accuracy0.9650364
# Iter 14,Testing Accuracy 0.9593,Training Accuracy0.9658545
# Iter 15,Testing Accuracy 0.962,Training Accuracy0.9678182
# Iter 16,Testing Accuracy 0.9632,Training Accuracy0.96827275
# Iter 17,Testing Accuracy 0.965,Training Accuracy0.96992725
# Iter 18,Testing Accuracy 0.9644,Training Accuracy0.97056365
# Iter 19,Testing Accuracy 0.9648,Training Accuracy0.9714909
# Iter 20,Testing Accuracy 0.9652,Training Accuracy0.97187275

# %% [markdown]
# 从输出上可以看出来，使用了Dropout之后的网络，在训练集和测试集上的准确率之间的差异间距变小了。
