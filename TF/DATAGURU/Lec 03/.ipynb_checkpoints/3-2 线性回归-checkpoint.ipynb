# %% [markdown]
# 第一个是3-1中重写写的非线性模型，下面再改变模型，去训练获取线性回归模型。

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

# %%
x_data = np.linspace(-0.5, 0.5, 200)[:, np.newaxis]
noise = np.random.normal(0, 0.02, x_data.shape)
y_data =np.square(x_data) + noise

# %%
plt.figure()
plt.scatter(x_data, y_data)
plt.show()

# %% [markdown]
# 由上图可见，生成的随机数，是成非线性的。

# %%
x = tf.placeholder(tf.float32, [None, 1])
y = tf.placeholder(tf.float32, [None, 1])

# %%
Weights_L1 = tf.Variable(tf.random_normal([1, 2]))
Biases_L1 = tf.Variable(tf.zeros([1, 2]))
op_L1 = tf.matmul(x, Weights_L1) + Biases_L1
L1_output = tf.nn.tanh(op_L1)

# %%
Weights_L2 = tf.Variable(tf.random_normal([2, 1]))
Biases_L2 = tf.Variable(tf.zeros([1,1]))
op_L2 = tf.matmul(L1_output, Weights_L2) + Biases_L2
L2_output = tf.nn.tanh(op_L2)

# %%
loss = tf.reduce_mean(tf.square(L2_output - y))

# %%
optimizer = tf.train.GradientDescentOptimizer(0.1)
train = optimizer.minimize(loss)

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(200000):
        sess.run(train, feed_dict={x: x_data, y: y_data})
        if epoch % 50000 ==0:
            print(sess.run(loss, feed_dict={x: x_data, y: y_data}))
    
    prediction_value = sess.run(L2_output, feed_dict={x: x_data, y: y_data})
    
    plt.figure()
    plt.scatter(x_data, y_data)
    plt.plot(x_data, prediction_value, 'r-', lw=5)
    plt.show()
# Out:
# 0.2660751
# 0.00047691524
# 0.0004622104
# 0.00045253313

# %% [markdown]
# ----

# %% [markdown]
# 下面是根据呈简单线性回归的数据，搭建的两层的神经网络模型，效果并不好。

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

x_data = np.linspace(-0.5, 0.5, 200)[:, np.newaxis]
noise = np.random.normal(0, 0.02, x_data.shape)
y_data =10*x_data + noise


x = tf.placeholder(tf.float32, [None, 1])
y = tf.placeholder(tf.float32, [None, 1])

Weights_L1 = tf.Variable(tf.random_normal([1, 2]))
Biases_L1 = tf.Variable(tf.zeros([1, 2]))
op_L1 = tf.matmul(x, Weights_L1) + Biases_L1
L1_output = tf.nn.tanh(op_L1)

Weights_L2 = tf.Variable(tf.random_normal([2, 1]))
Biases_L2 = tf.Variable(tf.zeros([1,1]))
op_L2 = tf.matmul(L1_output, Weights_L2) + Biases_L2
L2_output = tf.nn.tanh(op_L2)

loss = tf.reduce_mean(tf.square(L2_output - y))

optimizer = tf.train.GradientDescentOptimizer(0.1)
train = optimizer.minimize(loss)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(200000):
        sess.run(train, feed_dict={x: x_data, y: y_data})
        if epoch % 50000 ==0:
            print(sess.run(loss, feed_dict={x: x_data, y: y_data}))
    
    prediction_value = sess.run(L2_output, feed_dict={x: x_data, y: y_data})
    
    plt.figure()
    plt.scatter(x_data, y_data)
    plt.plot(x_data, prediction_value, 'r-', lw=5)
    plt.show()
# Out:
# 5.860005
# 4.3391113
# 4.3369203
# 4.33534

# %% [markdown]
# 下面将模型的隐层改成10个神经元的。

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

x_data = np.linspace(-0.5, 0.5, 200)[:, np.newaxis]
noise = np.random.normal(0, 0.02, x_data.shape)
y_data =10*x_data + noise


x = tf.placeholder(tf.float32, [None, 1])
y = tf.placeholder(tf.float32, [None, 1])

Weights_L1 = tf.Variable(tf.random_normal([1, 10]))
Biases_L1 = tf.Variable(tf.zeros([1, 10]))
op_L1 = tf.matmul(x, Weights_L1) + Biases_L1
L1_output = tf.nn.tanh(op_L1)

Weights_L2 = tf.Variable(tf.random_normal([10, 1]))
Biases_L2 = tf.Variable(tf.zeros([1,1]))
op_L2 = tf.matmul(L1_output, Weights_L2) + Biases_L2
L2_output = tf.nn.tanh(op_L2)

loss = tf.reduce_mean(tf.square(L2_output - y))

optimizer = tf.train.GradientDescentOptimizer(0.1)
train = optimizer.minimize(loss)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(200000):
        sess.run(train, feed_dict={x: x_data, y: y_data})
        if epoch % 50000 ==0:
            print(sess.run(loss, feed_dict={x: x_data, y: y_data}))
    
    prediction_value = sess.run(L2_output, feed_dict={x: x_data, y: y_data})
    
    plt.figure()
    plt.scatter(x_data, y_data)
    plt.plot(x_data, prediction_value, 'r-', lw=5)
    plt.show()
# Out:
# 5.4778795
# 4.342336
# 4.3422604
# 4.3422194

# %% [markdown]
# 效果看上去还是不好。

# %% [markdown]
# ---

# %% [markdown]
# 目标函数改成y=ax+b的线性模型。

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

x_data = np.linspace(-0.5, 0.5, 200)[:, np.newaxis]
noise = np.random.normal(0, 0.02, x_data.shape)
y_data =10*x_data + noise


x = tf.placeholder(tf.float32, [None, 1])
y = tf.placeholder(tf.float32, [None, 1])

a = tf.Variable(0.)
b = tf.Variable(0.)

linear_model = a*y + b

loss = tf.reduce_mean(tf.square(linear_model - y))

optimizer = tf.train.GradientDescentOptimizer(0.1)
train = optimizer.minimize(loss)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for epoch in range(200000):
        sess.run(train, feed_dict={x: x_data, y: y_data})
        if epoch % 50000 ==0:
            print(sess.run(loss, feed_dict={x: x_data, y: y_data}))
    
    prediction_value = sess.run(linear_model, feed_dict={x: x_data, y: y_data})
    
    plt.figure()
    plt.scatter(x_data, y_data)
    plt.plot(x_data, prediction_value, 'r-', lw=5)
    plt.show()
# Out:
# 3.9347427
# 1.101845e-13
# 1.101845e-13
# 1.101845e-13
